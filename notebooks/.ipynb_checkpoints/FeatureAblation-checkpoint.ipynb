# %% [markdown]
# # Evaluación de importancia de cada predictor bioquímico global

# %% [markdown]
# ## Vamos a ver cómo afecta cada predictor bioquímico por separado al rendimiento del modelo AMP-BERT-BIOCHEM

# %%
import pandas as pd
import torch

SEED = 0
FRAC_VAL = 0.2

torch.manual_seed(SEED)

train_df = pd.read_csv('./datasets/all_veltri_2.csv', index_col = 0).sample(frac=1, random_state=SEED)
df_pos = pd.read_csv('./datasets/veltri_dramp_cdhit_90_2.csv', index_col = 0)
df_neg = pd.read_csv('./datasets/non_amp_ampep_cdhit90_2.csv', index_col = 0)

val_df_pos = df_pos.sample(frac=FRAC_VAL, random_state=SEED)
val_df_neg = df_neg.sample(frac=FRAC_VAL, random_state=SEED)
test_df_pos = df_pos.drop(val_df_pos.index)
test_df_neg = df_neg.drop(val_df_neg.index)

val_df = pd.concat([val_df_pos, val_df_neg]).sample(frac=1, random_state=SEED)
test_df = pd.concat([test_df_pos, test_df_neg]).sample(frac=1, random_state=SEED)

print(f"Validation dataframe: {len(val_df_pos)} positives, {len(val_df_neg)} negatives ({len(val_df_pos)/len(val_df)}%)")
print(f"Test dataframe: {len(test_df_pos)} positives, {len(test_df_neg)} negatives ({len(test_df_pos)/len(test_df)}%)")
# Out:
# Validation dataframe: 413 positives, 382 negatives (0.519496855345912%)
# Test dataframe: 1652 positives, 1526 negatives (0.5198237885462555%)

# %%
from pipeline_tools import AMP_BioChemDataLoader, train_model, eval_model, compute_metrics
from torch.optim import AdamW
from transformers import BertForSequenceClassification, get_linear_schedule_with_warmup
from MultiGPUModels import MultiGPUBertForPeptideClassification
import torch
from torch.nn import CrossEntropyLoss
from copy import deepcopy

BATCH_SIZE = 8
LEARNING_RATE = 5e-6
WEIGHT_DECAY = 0.01
EPOCHS = 1
            
biochem_cols = [
    "molecular_mass",
    "hydrophobic_freq",
    "hydrophilic_freq",
    "basic_freq",
    "acid_freq",
    "charge",
    "aliphatic_index",
    "average_hydrophobicity",
    "isoelectric_point"
]


bert_model = BertForSequenceClassification.from_pretrained('Rostlab/prot_bert_bfd')
# Out:
# Some weights of the model checkpoint at Rostlab/prot_bert_bfd were not used when initializing BertForSequenceClassification: ['cls.predictions.decoder.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at Rostlab/prot_bert_bfd and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def train_with_cols(biochem_cols):
    train_dataloader = AMP_BioChemDataLoader(train_df, biochem_cols, batch_size = BATCH_SIZE)            
    test_dataloader = AMP_BioChemDataLoader(test_df, biochem_cols, batch_size = BATCH_SIZE)            

    multi_gpu_bert_pred = MultiGPUBertForPeptideClassification(deepcopy(bert_model), biochem_cols)
            
    # Entrenar el modelo con esta configuracion
    optimizer = AdamW(
        multi_gpu_bert_pred.parameters(), 
        lr = LEARNING_RATE, 
        weight_decay = WEIGHT_DECAY)
            
    total_steps = len(train_dataloader) * EPOCHS
            
    scheduler = get_linear_schedule_with_warmup(optimizer, 
        num_warmup_steps = 0, 
        num_training_steps = total_steps)

    for i in range(EPOCHS):
        train_model(multi_gpu_bert_pred, train_dataloader, CrossEntropyLoss(), optimizer, scheduler, True)
            
    # Obtener las métricas de validacion
    test_labels, test_preds = eval_model(multi_gpu_bert_pred, test_dataloader, CrossEntropyLoss(), True)
    test_metrics = compute_metrics(test_labels, test_preds)

    print(f"Metrics for test set: ")
    print(test_metrics)
    
    del multi_gpu_bert_pred
    return test_metrics

# %%
for i in range(5):
    test_metrics_all_biochem = train_with_cols(biochem_cols)
    test_metrics_all_biochem.to_csv(f'./biochem_results/1test_metrics_all_biochem({i}).csv')
    
for i in range(5):
    test_metrics_no_biochem = train_with_cols([])
    test_metrics_no_biochem.to_csv(f'./biochem_results/1test_metrics_no_biochem({i}).csv')

    for biochem_pred in biochem_cols:
        test_metrics_pred = train_with_cols([biochem_pred])
        test_metrics_pred.to_csv(f'./biochem_results/1test_metrics_only_pred_{biochem_pred}({i}).csv')
# Out:
# Step 10/445: Loss (avg) 0.4773380806387357, Step Time 715 ms, ETA 5:11
# Step 20/445: Loss (avg) 0.6377482297083368, Step Time 718 ms, ETA 5:5
# Step 30/445: Loss (avg) 0.6915916700925424, Step Time 717 ms, ETA 4:57
# Step 40/445: Loss (avg) 0.6838727819970682, Step Time 721 ms, ETA 4:52
# Step 50/445: Loss (avg) 0.6612637778654892, Step Time 722 ms, ETA 4:45
# Step 60/445: Loss (avg) 0.6347442744300693, Step Time 720 ms, ETA 4:37
# Step 70/445: Loss (avg) 0.6021377031192134, Step Time 723 ms, ETA 4:31
# Step 80/445: Loss (avg) 0.5746518221323368, Step Time 725 ms, ETA 4:24
# Step 90/445: Loss (avg) 0.5575585261723798, Step Time 727 ms, ETA 4:18
# Step 100/445: Loss (avg) 0.5187445021319471, Step Time 724 ms, ETA 4:9
# Step 110/445: Loss (avg) 0.5033896873503731, Step Time 726 ms, ETA 4:3
# Step 120/445: Loss (avg) 0.4964198630607212, Step Time 724 ms, ETA 3:55
# Step 130/445: Loss (avg) 0.4527870477030367, Step Time 727 ms, ETA 3:49
# Step 140/445: Loss (avg) 0.5073909234324983, Step Time 726 ms, ETA 3:41
# Step 150/445: Loss (avg) 0.4638117999553122, Step Time 727 ms, ETA 3:34
# Step 160/445: Loss (avg) 0.4131597916595801, Step Time 728 ms, ETA 3:27
# Step 170/445: Loss (avg) 0.4131179044506308, Step Time 728 ms, ETA 3:20
# Step 180/445: Loss (avg) 0.3585221362747643, Step Time 729 ms, ETA 3:13
# Step 190/445: Loss (avg) 0.3380184801044192, Step Time 728 ms, ETA 3:5
# Step 200/445: Loss (avg) 0.31991490438824866, Step Time 730 ms, ETA 2:58
# Step 210/445: Loss (avg) 0.327502046513236, Step Time 727 ms, ETA 2:50
# Step 220/445: Loss (avg) 0.32260963471281834, Step Time 729 ms, ETA 2:44
# Step 230/445: Loss (avg) 0.3591535474515994, Step Time 730 ms, ETA 2:36
# Step 240/445: Loss (avg) 0.4176065373193397, Step Time 730 ms, ETA 2:29
# Step 250/445: Loss (avg) 0.36258704882725784, Step Time 730 ms, ETA 2:22
# Step 260/445: Loss (avg) 0.3832829139406457, Step Time 731 ms, ETA 2:15
# Step 270/445: Loss (avg) 0.3612586281609964, Step Time 729 ms, ETA 2:7
# Step 280/445: Loss (avg) 0.3145925125153842, Step Time 731 ms, ETA 2:0
# Step 290/445: Loss (avg) 0.3331936614417462, Step Time 730 ms, ETA 1:53
# Step 300/445: Loss (avg) 0.33181023706539886, Step Time 727 ms, ETA 1:45
# Step 310/445: Loss (avg) 0.30945205578704216, Step Time 734 ms, ETA 1:39
# Step 320/445: Loss (avg) 0.29951984932086945, Step Time 731 ms, ETA 1:31
# Step 330/445: Loss (avg) 0.26315142091878957, Step Time 731 ms, ETA 1:24
# Step 340/445: Loss (avg) 0.269644008831518, Step Time 727 ms, ETA 1:16
# Step 350/445: Loss (avg) 0.2444395376446969, Step Time 731 ms, ETA 1:9
# Step 360/445: Loss (avg) 0.2675847910046641, Step Time 730 ms, ETA 1:2
# Step 370/445: Loss (avg) 0.2626119818608163, Step Time 733 ms, ETA 0:54
# Step 380/445: Loss (avg) 0.3285952418858536, Step Time 724 ms, ETA 0:47
# Step 390/445: Loss (avg) 0.3256728983221729, Step Time 731 ms, ETA 0:40
# Step 400/445: Loss (avg) 0.2524161431795256, Step Time 732 ms, ETA 0:32
# Step 410/445: Loss (avg) 0.28002368645742765, Step Time 736 ms, ETA 0:25
# Step 420/445: Loss (avg) 0.32401810934802405, Step Time 734 ms, ETA 0:18
# Step 430/445: Loss (avg) 0.22292526945123592, Step Time 731 ms, ETA 0:10
# Step 440/445: Loss (avg) 0.24553451746675273, Step Time 729 ms, ETA 0:3
# Step 10/398: Loss (avg) 0.2713132238194692, Step Time 236 ms, ETA 1:31
# Step 20/398: Loss (avg) 0.46317293197662834, Step Time 236 ms, ETA 1:29
# Step 30/398: Loss (avg) 0.537485626524257, Step Time 236 ms, ETA 1:26
# Step 40/398: Loss (avg) 0.6261836941320819, Step Time 235 ms, ETA 1:24
# Step 50/398: Loss (avg) 0.6725764692091363, Step Time 236 ms, ETA 1:22
# Step 60/398: Loss (avg) 0.5916159628280083, Step Time 236 ms, ETA 1:19
# Step 70/398: Loss (avg) 0.44199642537553246, Step Time 236 ms, ETA 1:17
# Step 80/398: Loss (avg) 0.5811449316983559, Step Time 238 ms, ETA 1:15
# Step 90/398: Loss (avg) 0.5860342106081234, Step Time 237 ms, ETA 1:12
# Step 100/398: Loss (avg) 0.5172543006384398, Step Time 236 ms, ETA 1:10
# Step 110/398: Loss (avg) 0.5392705600184222, Step Time 235 ms, ETA 1:7
# Step 120/398: Loss (avg) 0.4489586265301314, Step Time 236 ms, ETA 1:5
# Step 130/398: Loss (avg) 0.5008337233947907, Step Time 237 ms, ETA 1:3
# Step 140/398: Loss (avg) 0.5902448532785936, Step Time 237 ms, ETA 1:1
# Step 150/398: Loss (avg) 0.47796095884105166, Step Time 235 ms, ETA 0:58
# Step 160/398: Loss (avg) 0.44662759395775725, Step Time 236 ms, ETA 0:56
# Step 170/398: Loss (avg) 0.5176475743506368, Step Time 235 ms, ETA 0:53
# Step 180/398: Loss (avg) 0.5495749965692921, Step Time 236 ms, ETA 0:51
# Step 190/398: Loss (avg) 0.563602623675668, Step Time 237 ms, ETA 0:49
# Step 200/398: Loss (avg) 0.4985246779004154, Step Time 236 ms, ETA 0:46
# Step 210/398: Loss (avg) 0.5474162639365644, Step Time 236 ms, ETA 0:44
# Step 220/398: Loss (avg) 0.548699767766158, Step Time 236 ms, ETA 0:42
# Step 230/398: Loss (avg) 0.6245190348516553, Step Time 235 ms, ETA 0:39
# Step 240/398: Loss (avg) 0.5736441656989884, Step Time 238 ms, ETA 0:37
# Step 250/398: Loss (avg) 0.6381488911779257, Step Time 237 ms, ETA 0:35
# Step 260/398: Loss (avg) 0.5755145937394802, Step Time 236 ms, ETA 0:32
# Step 270/398: Loss (avg) 0.5030957063232618, Step Time 235 ms, ETA 0:30
# Step 280/398: Loss (avg) 0.512385696177088, Step Time 235 ms, ETA 0:27
# Step 290/398: Loss (avg) 0.5101922942075052, Step Time 236 ms, ETA 0:25
# Step 300/398: Loss (avg) 0.564806603852401, Step Time 236 ms, ETA 0:23
# Step 310/398: Loss (avg) 0.5852132145023252, Step Time 235 ms, ETA 0:20
# Step 320/398: Loss (avg) 0.6939947037758236, Step Time 236 ms, ETA 0:18
# Step 330/398: Loss (avg) 0.5871424192097889, Step Time 237 ms, ETA 0:16
# Step 340/398: Loss (avg) 0.49375770780278616, Step Time 236 ms, ETA 0:13
# Step 350/398: Loss (avg) 0.6052412936365484, Step Time 238 ms, ETA 0:11
# Step 360/398: Loss (avg) 0.5383500163339182, Step Time 236 ms, ETA 0:8
# Step 370/398: Loss (avg) 0.633802221411269, Step Time 235 ms, ETA 0:6
# Step 380/398: Loss (avg) 0.4754410606187382, Step Time 236 ms, ETA 0:4
# Step 390/398: Loss (avg) 0.48158878539187067, Step Time 236 ms, ETA 0:1
# Metrics for test set:
#    accuracy        f1  precision    recall  specificity     auroc      aupr  \
# 0  0.781624  0.804065   0.753439  0.861985     0.694626  0.778306  0.843584
#
#              confusion_matrix
# 0  [[1060, 466], [228, 1424]]
# Step 10/445: Loss (avg) 0.44673702496601875, Step Time 725 ms, ETA 5:15
# Step 20/445: Loss (avg) 0.5759039702345301, Step Time 724 ms, ETA 5:7
# Step 30/445: Loss (avg) 0.6303501335557029, Step Time 726 ms, ETA 5:1
# Step 40/445: Loss (avg) 0.6425418534155011, Step Time 726 ms, ETA 4:54
# Step 50/445: Loss (avg) 0.6294718691849529, Step Time 728 ms, ETA 4:47
# Step 60/445: Loss (avg) 0.5889541695063893, Step Time 727 ms, ETA 4:39
# Step 70/445: Loss (avg) 0.5912315935262181, Step Time 729 ms, ETA 4:33
# Step 80/445: Loss (avg) 0.5355927293499588, Step Time 732 ms, ETA 4:27
# Step 90/445: Loss (avg) 0.4917225365415025, Step Time 732 ms, ETA 4:19
# Step 100/445: Loss (avg) 0.44863764163467146, Step Time 732 ms, ETA 4:12
# Step 110/445: Loss (avg) 0.462047343072215, Step Time 730 ms, ETA 4:4
# Step 120/445: Loss (avg) 0.44618697351909087, Step Time 730 ms, ETA 3:57
# Step 130/445: Loss (avg) 0.42611146228853697, Step Time 722 ms, ETA 3:47
# Step 140/445: Loss (avg) 0.4077563070835394, Step Time 732 ms, ETA 3:43
# Step 150/445: Loss (avg) 0.3787032059402319, Step Time 734 ms, ETA 3:36
# Step 160/445: Loss (avg) 0.3875474535244291, Step Time 728 ms, ETA 3:27
# Step 170/445: Loss (avg) 0.3906839456524145, Step Time 733 ms, ETA 3:21
# Step 180/445: Loss (avg) 0.35615833279737724, Step Time 733 ms, ETA 3:14
# Step 190/445: Loss (avg) 0.32943698144220007, Step Time 729 ms, ETA 3:5
# Step 200/445: Loss (avg) 0.3086556709932212, Step Time 732 ms, ETA 2:59
# Step 210/445: Loss (avg) 0.3158833234888117, Step Time 733 ms, ETA 2:52
# Step 220/445: Loss (avg) 0.2666582446641266, Step Time 731 ms, ETA 2:44
# Step 230/445: Loss (avg) 0.25430036196959965, Step Time 731 ms, ETA 2:37
# Step 240/445: Loss (avg) 0.2785006727911874, Step Time 734 ms, ETA 2:30
# Step 250/445: Loss (avg) 0.3005260519623426, Step Time 734 ms, ETA 2:23
# Step 260/445: Loss (avg) 0.2745727497054457, Step Time 733 ms, ETA 2:15
# Step 270/445: Loss (avg) 0.25525653998739256, Step Time 733 ms, ETA 2:8
# Step 280/445: Loss (avg) 0.30022012670147336, Step Time 734 ms, ETA 2:1
# Step 290/445: Loss (avg) 0.26860096372381365, Step Time 735 ms, ETA 1:53
# Step 300/445: Loss (avg) 0.23242065195358272, Step Time 730 ms, ETA 1:45
# Step 310/445: Loss (avg) 0.23962841067169321, Step Time 736 ms, ETA 1:39
# Step 320/445: Loss (avg) 0.24906415104320534, Step Time 734 ms, ETA 1:31
# Step 330/445: Loss (avg) 0.31246627192907056, Step Time 731 ms, ETA 1:24
# Step 340/445: Loss (avg) 0.2360313855353426, Step Time 731 ms, ETA 1:16
# Step 350/445: Loss (avg) 0.2456182524790713, Step Time 734 ms, ETA 1:9
# Step 360/445: Loss (avg) 0.28355640458297904, Step Time 734 ms, ETA 1:2
# Step 370/445: Loss (avg) 0.27912396363868225, Step Time 732 ms, ETA 0:54
# Step 380/445: Loss (avg) 0.27735112895619124, Step Time 733 ms, ETA 0:47
# Step 390/445: Loss (avg) 0.23091439971114555, Step Time 732 ms, ETA 0:40
# Step 400/445: Loss (avg) 0.2321691942934921, Step Time 734 ms, ETA 0:33
# Step 410/445: Loss (avg) 0.24608481412391428, Step Time 735 ms, ETA 0:25
# Step 420/445: Loss (avg) 0.2542384369754575, Step Time 733 ms, ETA 0:18
# Step 430/445: Loss (avg) 0.3113063410222996, Step Time 733 ms, ETA 0:10
# Step 440/445: Loss (avg) 0.21659835970650793, Step Time 734 ms, ETA 0:3
# Step 10/398: Loss (avg) 0.41267730830840677, Step Time 237 ms, ETA 1:31
# Step 20/398: Loss (avg) 0.5919085283102636, Step Time 235 ms, ETA 1:28
# Step 30/398: Loss (avg) 0.6547822002787421, Step Time 235 ms, ETA 1:26
# Step 40/398: Loss (avg) 0.6238276206320681, Step Time 236 ms, ETA 1:24
# Step 50/398: Loss (avg) 0.508724107842153, Step Time 236 ms, ETA 1:22
# Step 60/398: Loss (avg) 0.43928318497088426, Step Time 236 ms, ETA 1:19
# Step 70/398: Loss (avg) 0.5349395293344597, Step Time 235 ms, ETA 1:17
# Step 80/398: Loss (avg) 0.5699233202436043, Step Time 235 ms, ETA 1:14
# Step 90/398: Loss (avg) 0.5373983079722727, Step Time 236 ms, ETA 1:12
# Step 100/398: Loss (avg) 0.6338606835954108, Step Time 236 ms, ETA 1:10
# Step 110/398: Loss (avg) 0.5629235134744979, Step Time 238 ms, ETA 1:8
# Step 120/398: Loss (avg) 0.5149589696190977, Step Time 236 ms, ETA 1:5
# Step 130/398: Loss (avg) 0.5627185660552864, Step Time 236 ms, ETA 1:3
# Step 140/398: Loss (avg) 0.4846344635853168, Step Time 235 ms, ETA 1:0
# Step 150/398: Loss (avg) 0.48210760547203535, Step Time 237 ms, ETA 0:58
# Step 160/398: Loss (avg) 0.6473275758829025, Step Time 238 ms, ETA 0:56
# Step 170/398: Loss (avg) 0.6216848743148492, Step Time 237 ms, ETA 0:54
# Step 180/398: Loss (avg) 0.5486656666350535, Step Time 237 ms, ETA 0:51
# Step 190/398: Loss (avg) 0.585875329406199, Step Time 235 ms, ETA 0:48
# Step 200/398: Loss (avg) 0.6326596551320325, Step Time 235 ms, ETA 0:46
# Step 210/398: Loss (avg) 0.7188786477360838, Step Time 236 ms, ETA 0:44
# Step 220/398: Loss (avg) 0.6474795127040152, Step Time 238 ms, ETA 0:42
# Step 230/398: Loss (avg) 0.5721035578186042, Step Time 237 ms, ETA 0:39
# Step 240/398: Loss (avg) 0.5280506966990623, Step Time 235 ms, ETA 0:37
# Step 250/398: Loss (avg) 0.6092315898534933, Step Time 235 ms, ETA 0:34
# Step 260/398: Loss (avg) 0.5324981616230812, Step Time 236 ms, ETA 0:32
# Step 270/398: Loss (avg) 0.6192013443353248, Step Time 236 ms, ETA 0:30
# Step 280/398: Loss (avg) 0.7010637204159899, Step Time 238 ms, ETA 0:28
# Step 290/398: Loss (avg) 0.6587359239879951, Step Time 235 ms, ETA 0:25
# Step 300/398: Loss (avg) 0.6145714099300529, Step Time 236 ms, ETA 0:23
# Step 310/398: Loss (avg) 0.6293897964591821, Step Time 236 ms, ETA 0:20
# Step 320/398: Loss (avg) 0.5476952729027686, Step Time 236 ms, ETA 0:18
# Step 330/398: Loss (avg) 0.5706352465312544, Step Time 238 ms, ETA 0:16
# Step 340/398: Loss (avg) 0.5975636130326063, Step Time 235 ms, ETA 0:13
# Step 350/398: Loss (avg) 0.5322610763176053, Step Time 236 ms, ETA 0:11
# Step 360/398: Loss (avg) 0.6186247998964111, Step Time 236 ms, ETA 0:8
# Step 370/398: Loss (avg) 0.69915546092024, Step Time 237 ms, ETA 0:6
# Step 380/398: Loss (avg) 0.6112930373968233, Step Time 237 ms, ETA 0:4
# Step 390/398: Loss (avg) 0.5191785686572657, Step Time 236 ms, ETA 0:1
# Metrics for test set:
#    accuracy        f1  precision    recall  specificity     auroc      aupr  \
# 0  0.776589  0.800897   0.746082  0.864407      0.68152  0.772964  0.840486
#
#              confusion_matrix
# 0  [[1040, 486], [224, 1428]]
# Step 10/445: Loss (avg) 0.482029809650846, Step Time 715 ms, ETA 5:11
# Step 20/445: Loss (avg) 0.622166841071562, Step Time 727 ms, ETA 5:8
# Step 30/445: Loss (avg) 0.6677730408417705, Step Time 726 ms, ETA 5:1
# Step 40/445: Loss (avg) 0.6886392754361323, Step Time 727 ms, ETA 4:54
# Step 50/445: Loss (avg) 0.657391534493262, Step Time 727 ms, ETA 4:47
# Step 60/445: Loss (avg) 0.6384243260287711, Step Time 730 ms, ETA 4:41
# Step 70/445: Loss (avg) 0.5986933785460197, Step Time 728 ms, ETA 4:33
# Step 80/445: Loss (avg) 0.5584864151304494, Step Time 736 ms, ETA 4:28
# Step 90/445: Loss (avg) 0.5424650022651327, Step Time 732 ms, ETA 4:19
# Step 100/445: Loss (avg) 0.518592255574907, Step Time 733 ms, ETA 4:12
# Step 110/445: Loss (avg) 0.47011209985480024, Step Time 731 ms, ETA 4:4
# Step 120/445: Loss (avg) 0.4540152789871015, Step Time 731 ms, ETA 3:57
# Step 130/445: Loss (avg) 0.42076467633479686, Step Time 730 ms, ETA 3:49
# Step 140/445: Loss (avg) 0.42266658773727694, Step Time 732 ms, ETA 3:43
# Step 150/445: Loss (avg) 0.3862979937418054, Step Time 733 ms, ETA 3:36
# Step 160/445: Loss (avg) 0.3944878096111065, Step Time 733 ms, ETA 3:28
# Step 170/445: Loss (avg) 0.3322074383969003, Step Time 731 ms, ETA 3:21
# Step 180/445: Loss (avg) 0.410388734314042, Step Time 732 ms, ETA 3:13
# Step 190/445: Loss (avg) 0.38223583651130555, Step Time 734 ms, ETA 3:7
# Step 200/445: Loss (avg) 0.37759867842347256, Step Time 732 ms, ETA 2:59
# Step 210/445: Loss (avg) 0.34028076518264316, Step Time 734 ms, ETA 2:52
# Step 220/445: Loss (avg) 0.2876578192920084, Step Time 734 ms, ETA 2:45
# Step 230/445: Loss (avg) 0.3175039644780098, Step Time 732 ms, ETA 2:37
# Step 240/445: Loss (avg) 0.28402020944984296, Step Time 736 ms, ETA 2:30
# Step 250/445: Loss (avg) 0.30875540837541354, Step Time 732 ms, ETA 2:22
# Step 260/445: Loss (avg) 0.33427036472702887, Step Time 733 ms, ETA 2:15
# Step 270/445: Loss (avg) 0.3406847910492818, Step Time 734 ms, ETA 2:8
# Step 280/445: Loss (avg) 0.27913587880305607, Step Time 725 ms, ETA 1:59
# Step 290/445: Loss (avg) 0.28624744288631687, Step Time 735 ms, ETA 1:53
# Step 300/445: Loss (avg) 0.3259919391007465, Step Time 733 ms, ETA 1:46
# Step 310/445: Loss (avg) 0.2561798114217867, Step Time 733 ms, ETA 1:38
# Step 320/445: Loss (avg) 0.29122746612796496, Step Time 735 ms, ETA 1:31
# Step 330/445: Loss (avg) 0.2449504463096752, Step Time 733 ms, ETA 1:24
# Step 340/445: Loss (avg) 0.21524516978088168, Step Time 733 ms, ETA 1:16
# Step 350/445: Loss (avg) 0.23507411969986436, Step Time 735 ms, ETA 1:9
# Step 360/445: Loss (avg) 0.2579102767304444, Step Time 729 ms, ETA 1:1
# Step 370/445: Loss (avg) 0.274412301013865, Step Time 733 ms, ETA 0:54
# Step 380/445: Loss (avg) 0.28483936940123256, Step Time 735 ms, ETA 0:47
# Step 390/445: Loss (avg) 0.23850548485991166, Step Time 734 ms, ETA 0:40
# Step 400/445: Loss (avg) 0.25642799695727275, Step Time 735 ms, ETA 0:33
# Step 410/445: Loss (avg) 0.18761979509907345, Step Time 725 ms, ETA 0:25
# Step 420/445: Loss (avg) 0.22168735829841513, Step Time 734 ms, ETA 0:18
# Step 430/445: Loss (avg) 0.34212786126616285, Step Time 734 ms, ETA 0:11
# Step 440/445: Loss (avg) 0.21685160957980723, Step Time 732 ms, ETA 0:3
# Step 10/398: Loss (avg) 0.4040123352175591, Step Time 236 ms, ETA 1:31
# Step 20/398: Loss (avg) 0.47197566999217894, Step Time 235 ms, ETA 1:28
# Step 30/398: Loss (avg) 0.5505341812776207, Step Time 236 ms, ETA 1:26
# Step 40/398: Loss (avg) 0.7608221797006179, Step Time 236 ms, ETA 1:24
# Step 50/398: Loss (avg) 0.5994470261947485, Step Time 237 ms, ETA 1:22
# Step 60/398: Loss (avg) 0.44185241231862693, Step Time 237 ms, ETA 1:20
# Step 70/398: Loss (avg) 0.3882182787663926, Step Time 236 ms, ETA 1:17
# Step 80/398: Loss (avg) 0.4607828785994404, Step Time 235 ms, ETA 1:14
# Step 90/398: Loss (avg) 0.5246795319235322, Step Time 236 ms, ETA 1:12
# Step 100/398: Loss (avg) 0.5959085040351417, Step Time 237 ms, ETA 1:10
# Step 110/398: Loss (avg) 0.6243343181723688, Step Time 238 ms, ETA 1:8
# Step 120/398: Loss (avg) 0.49613968947510567, Step Time 236 ms, ETA 1:5
# Step 130/398: Loss (avg) 0.5310518701476388, Step Time 235 ms, ETA 1:2
# Step 140/398: Loss (avg) 0.6594892870797253, Step Time 236 ms, ETA 1:0
# Step 150/398: Loss (avg) 0.5364877158168226, Step Time 237 ms, ETA 0:58
# Step 160/398: Loss (avg) 0.5962833244754849, Step Time 236 ms, ETA 0:56
# Step 170/398: Loss (avg) 0.5302690366430591, Step Time 236 ms, ETA 0:53
# Step 180/398: Loss (avg) 0.6054362340799267, Step Time 236 ms, ETA 0:51
# Step 190/398: Loss (avg) 0.5335056622950148, Step Time 237 ms, ETA 0:49
# Step 200/398: Loss (avg) 0.5838981390416964, Step Time 237 ms, ETA 0:46
# Step 210/398: Loss (avg) 0.5804259708570775, Step Time 237 ms, ETA 0:44
# Step 220/398: Loss (avg) 0.6029772612996882, Step Time 237 ms, ETA 0:42
# Step 230/398: Loss (avg) 0.5855001513356893, Step Time 236 ms, ETA 0:39
# Step 240/398: Loss (avg) 0.4998849093366819, Step Time 237 ms, ETA 0:37
# Step 250/398: Loss (avg) 0.5427584628264536, Step Time 237 ms, ETA 0:35
# Step 260/398: Loss (avg) 0.579889104119411, Step Time 237 ms, ETA 0:32
# Step 270/398: Loss (avg) 0.5087050746368202, Step Time 237 ms, ETA 0:30
# Step 280/398: Loss (avg) 0.5335534473187027, Step Time 238 ms, ETA 0:28
# Step 290/398: Loss (avg) 0.47832989323623754, Step Time 236 ms, ETA 0:25
# Step 300/398: Loss (avg) 0.5365026758085686, Step Time 236 ms, ETA 0:23
# Step 310/398: Loss (avg) 0.6178751749863406, Step Time 237 ms, ETA 0:20
# Step 320/398: Loss (avg) 0.6002605026568832, Step Time 237 ms, ETA 0:18
# Step 330/398: Loss (avg) 0.4968426416338362, Step Time 236 ms, ETA 0:16
# Step 340/398: Loss (avg) 0.529315887033495, Step Time 239 ms, ETA 0:13
# Step 350/398: Loss (avg) 0.47492494113395173, Step Time 236 ms, ETA 0:11
# Step 360/398: Loss (avg) 0.5535210136002492, Step Time 236 ms, ETA 0:8
# Step 370/398: Loss (avg) 0.5408429087780608, Step Time 237 ms, ETA 0:6
# Step 380/398: Loss (avg) 0.7277759609281143, Step Time 237 ms, ETA 0:4
# Step 390/398: Loss (avg) 0.5556251193503415, Step Time 236 ms, ETA 0:1
# Metrics for test set:
#    accuracy        f1  precision    recall  specificity    auroc      aupr  \
# 0  0.785085  0.805911   0.759507  0.858354     0.705767  0.78206  0.845746
#
#              confusion_matrix
# 0  [[1077, 449], [234, 1418]]
# Step 10/445: Loss (avg) 0.47323558699395685, Step Time 726 ms, ETA 5:15
# Step 20/445: Loss (avg) 0.6342761599788, Step Time 725 ms, ETA 5:8
# Step 30/445: Loss (avg) 0.6799544017959069, Step Time 726 ms, ETA 5:1
# Step 40/445: Loss (avg) 0.6888414553524941, Step Time 726 ms, ETA 4:54
# Step 50/445: Loss (avg) 0.6736074116112415, Step Time 723 ms, ETA 4:45
# Step 60/445: Loss (avg) 0.6431613605019861, Step Time 731 ms, ETA 4:41
# Step 70/445: Loss (avg) 0.6203822053783483, Step Time 732 ms, ETA 4:34
# Step 80/445: Loss (avg) 0.5808234655589419, Step Time 728 ms, ETA 4:25
# Step 90/445: Loss (avg) 0.5719890170948325, Step Time 733 ms, ETA 4:20
# Step 100/445: Loss (avg) 0.5287089866874077, Step Time 732 ms, ETA 4:12
# Step 110/445: Loss (avg) 0.5131716984611417, Step Time 732 ms, ETA 4:5
# Step 120/445: Loss (avg) 0.473120554667547, Step Time 734 ms, ETA 3:58
# Step 130/445: Loss (avg) 0.44221425594845176, Step Time 734 ms, ETA 3:51
# Step 140/445: Loss (avg) 0.4352744637339179, Step Time 734 ms, ETA 3:43
# Step 150/445: Loss (avg) 0.4031645497615959, Step Time 734 ms, ETA 3:36
# Step 160/445: Loss (avg) 0.43116483467952116, Step Time 734 ms, ETA 3:29
# Step 170/445: Loss (avg) 0.3869476329749272, Step Time 732 ms, ETA 3:21
# Step 180/445: Loss (avg) 0.4404790835008667, Step Time 732 ms, ETA 3:13
# Step 190/445: Loss (avg) 0.4369696487045846, Step Time 734 ms, ETA 3:7
# Step 200/445: Loss (avg) 0.3743016191849228, Step Time 733 ms, ETA 2:59
# Step 210/445: Loss (avg) 0.2972246182929863, Step Time 733 ms, ETA 2:52
# Step 220/445: Loss (avg) 0.32268301204553285, Step Time 733 ms, ETA 2:44
# Step 230/445: Loss (avg) 0.31125201398994423, Step Time 733 ms, ETA 2:37
# Step 240/445: Loss (avg) 0.34849326545671655, Step Time 735 ms, ETA 2:30
# Step 250/445: Loss (avg) 0.31646989735114783, Step Time 733 ms, ETA 2:22
# Step 260/445: Loss (avg) 0.3192088512147497, Step Time 735 ms, ETA 2:15
# Step 270/445: Loss (avg) 0.3546634210895759, Step Time 735 ms, ETA 2:8
# Step 280/445: Loss (avg) 0.28658872301967575, Step Time 735 ms, ETA 2:1
# Step 290/445: Loss (avg) 0.28236281454452195, Step Time 734 ms, ETA 1:53
# Step 300/445: Loss (avg) 0.33699154879912885, Step Time 734 ms, ETA 1:46
# Step 310/445: Loss (avg) 0.3119557465772981, Step Time 733 ms, ETA 1:38
# Step 320/445: Loss (avg) 0.3864820218926302, Step Time 737 ms, ETA 1:32
# Step 330/445: Loss (avg) 0.3163318926891898, Step Time 734 ms, ETA 1:24
# Step 340/445: Loss (avg) 0.2641146431544735, Step Time 736 ms, ETA 1:17
# Step 350/445: Loss (avg) 0.27243290596952335, Step Time 735 ms, ETA 1:9
# Step 360/445: Loss (avg) 0.28652762790551173, Step Time 737 ms, ETA 1:2
# Step 370/445: Loss (avg) 0.3044169384614596, Step Time 734 ms, ETA 0:55
# Step 380/445: Loss (avg) 0.2703179385782387, Step Time 726 ms, ETA 0:47
# Step 390/445: Loss (avg) 0.2949918449501713, Step Time 733 ms, ETA 0:40
# Step 400/445: Loss (avg) 0.2553680996227438, Step Time 733 ms, ETA 0:32
# Step 410/445: Loss (avg) 0.2468015856261137, Step Time 734 ms, ETA 0:25
# Step 420/445: Loss (avg) 0.2647375041961063, Step Time 735 ms, ETA 0:18
# Step 430/445: Loss (avg) 0.2354861372609671, Step Time 735 ms, ETA 0:11
# Step 440/445: Loss (avg) 0.2800873372729471, Step Time 735 ms, ETA 0:3
# Step 10/398: Loss (avg) 0.3978528678525172, Step Time 236 ms, ETA 1:31
# Step 20/398: Loss (avg) 0.5422340416203997, Step Time 237 ms, ETA 1:29
# Step 30/398: Loss (avg) 0.5043124901022085, Step Time 238 ms, ETA 1:27
# Step 40/398: Loss (avg) 0.5734689508212096, Step Time 236 ms, ETA 1:24
# Step 50/398: Loss (avg) 0.5792162725462655, Step Time 236 ms, ETA 1:22
# Step 60/398: Loss (avg) 0.6612565281957012, Step Time 236 ms, ETA 1:19
# Step 70/398: Loss (avg) 0.5671968040091605, Step Time 237 ms, ETA 1:17
# Step 80/398: Loss (avg) 0.42184026384146217, Step Time 237 ms, ETA 1:15
# Step 90/398: Loss (avg) 0.513044579398526, Step Time 239 ms, ETA 1:13
# Step 100/398: Loss (avg) 0.4591823369488192, Step Time 236 ms, ETA 1:10
# Step 110/398: Loss (avg) 0.5036076126131551, Step Time 236 ms, ETA 1:7
# Step 120/398: Loss (avg) 0.511987163030016, Step Time 237 ms, ETA 1:5
# Step 130/398: Loss (avg) 0.7798972368514644, Step Time 237 ms, ETA 1:3
# Step 140/398: Loss (avg) 0.6489947241628358, Step Time 236 ms, ETA 1:0
# Step 150/398: Loss (avg) 0.5124806810951975, Step Time 239 ms, ETA 0:59
# Step 160/398: Loss (avg) 0.3812380844729661, Step Time 236 ms, ETA 0:56
# Step 170/398: Loss (avg) 0.5980310226492517, Step Time 236 ms, ETA 0:53
# Step 180/398: Loss (avg) 0.5625619432427065, Step Time 237 ms, ETA 0:51
# Step 190/398: Loss (avg) 0.4298113837095979, Step Time 237 ms, ETA 0:49
# Step 200/398: Loss (avg) 0.4815470230294836, Step Time 238 ms, ETA 0:47
# Step 210/398: Loss (avg) 0.3997751114132077, Step Time 238 ms, ETA 0:44
# Step 220/398: Loss (avg) 0.49819018104248375, Step Time 235 ms, ETA 0:41
# Step 230/398: Loss (avg) 0.48852147750084884, Step Time 236 ms, ETA 0:39
# Step 240/398: Loss (avg) 0.5383328283610133, Step Time 237 ms, ETA 0:37
# Step 250/398: Loss (avg) 0.5179736244379776, Step Time 236 ms, ETA 0:34
# Step 260/398: Loss (avg) 0.5908156305248676, Step Time 237 ms, ETA 0:32
# Step 270/398: Loss (avg) 0.6255993864791904, Step Time 237 ms, ETA 0:30
# Step 280/398: Loss (avg) 0.6496941611895037, Step Time 237 ms, ETA 0:27
# Step 290/398: Loss (avg) 0.58228837878117, Step Time 237 ms, ETA 0:25
# Step 300/398: Loss (avg) 0.4960004390498134, Step Time 236 ms, ETA 0:23
# Step 310/398: Loss (avg) 0.510076069056697, Step Time 237 ms, ETA 0:20
# Step 320/398: Loss (avg) 0.503163887671908, Step Time 238 ms, ETA 0:18
# Step 330/398: Loss (avg) 0.471996483759054, Step Time 237 ms, ETA 0:16
# Step 340/398: Loss (avg) 0.5529489253954306, Step Time 237 ms, ETA 0:13
# Step 350/398: Loss (avg) 0.5331032600081985, Step Time 237 ms, ETA 0:11
# Step 360/398: Loss (avg) 0.47411026109424087, Step Time 236 ms, ETA 0:8
# Step 370/398: Loss (avg) 0.46065004553532485, Step Time 235 ms, ETA 0:6
# Step 380/398: Loss (avg) 0.4756612981626953, Step Time 237 ms, ETA 0:4
# Step 390/398: Loss (avg) 0.49724144918370206, Step Time 237 ms, ETA 0:1
# Metrics for test set:
#    accuracy        f1  precision    recall  specificity     auroc      aupr  \
# 0  0.795469  0.812356    0.77649  0.851695       0.7346  0.793148  0.852639
#
#              confusion_matrix
# 0  [[1121, 405], [245, 1407]]
# Step 10/445: Loss (avg) 0.4449974022391375, Step Time 725 ms, ETA 5:15
# Step 20/445: Loss (avg) 0.5650560397209602, Step Time 725 ms, ETA 5:8
# Step 30/445: Loss (avg) 0.6116837356049704, Step Time 726 ms, ETA 5:1
# Step 40/445: Loss (avg) 0.6241492081094404, Step Time 728 ms, ETA 4:54
# Step 50/445: Loss (avg) 0.6047938308994607, Step Time 722 ms, ETA 4:45
# Step 60/445: Loss (avg) 0.6135310882566564, Step Time 727 ms, ETA 4:39
# Step 70/445: Loss (avg) 0.5882585807080343, Step Time 729 ms, ETA 4:33
# Step 80/445: Loss (avg) 0.5690070447420664, Step Time 730 ms, ETA 4:26
# Step 90/445: Loss (avg) 0.5053671410696601, Step Time 731 ms, ETA 4:19
# Step 100/445: Loss (avg) 0.5183823451027371, Step Time 733 ms, ETA 4:12
# Step 110/445: Loss (avg) 0.492911265571007, Step Time 732 ms, ETA 4:5
# Step 120/445: Loss (avg) 0.46201815687954906, Step Time 732 ms, ETA 3:57
# Step 130/445: Loss (avg) 0.46087462179871946, Step Time 733 ms, ETA 3:50
# Step 140/445: Loss (avg) 0.3902133497004392, Step Time 733 ms, ETA 3:43
# Step 150/445: Loss (avg) 0.4034171808202745, Step Time 733 ms, ETA 3:36
# Step 160/445: Loss (avg) 0.4203230562915706, Step Time 735 ms, ETA 3:29
# Step 170/445: Loss (avg) 0.4021772205492532, Step Time 735 ms, ETA 3:22
# Step 180/445: Loss (avg) 0.37931942212449576, Step Time 734 ms, ETA 3:14
# Step 190/445: Loss (avg) 0.3424973472639614, Step Time 729 ms, ETA 3:5
# Step 200/445: Loss (avg) 0.35610869100187525, Step Time 734 ms, ETA 2:59
# Step 210/445: Loss (avg) 0.38420369838019425, Step Time 732 ms, ETA 2:52
# Step 220/445: Loss (avg) 0.3389053718482497, Step Time 735 ms, ETA 2:45
# Step 230/445: Loss (avg) 0.3003913282893901, Step Time 735 ms, ETA 2:38
# Step 240/445: Loss (avg) 0.275397296914206, Step Time 732 ms, ETA 2:30
# Step 250/445: Loss (avg) 0.28097853841517845, Step Time 732 ms, ETA 2:22
# Step 260/445: Loss (avg) 0.33220834660739323, Step Time 733 ms, ETA 2:15
# Step 270/445: Loss (avg) 0.2830970725769492, Step Time 734 ms, ETA 2:8
# Step 280/445: Loss (avg) 0.21356864056510785, Step Time 736 ms, ETA 2:1
# Step 290/445: Loss (avg) 0.23098797015033676, Step Time 729 ms, ETA 1:52
# Step 300/445: Loss (avg) 0.28278243092915467, Step Time 734 ms, ETA 1:46
# Step 310/445: Loss (avg) 0.2767212789384865, Step Time 736 ms, ETA 1:39
# Step 320/445: Loss (avg) 0.3234847181073559, Step Time 742 ms, ETA 1:32
# Step 330/445: Loss (avg) 0.29987702628947843, Step Time 733 ms, ETA 1:24
# Step 340/445: Loss (avg) 0.26243537267170963, Step Time 735 ms, ETA 1:17
# Step 350/445: Loss (avg) 0.26675757775030284, Step Time 734 ms, ETA 1:9
# Step 360/445: Loss (avg) 0.27020253581775194, Step Time 735 ms, ETA 1:2
# Step 370/445: Loss (avg) 0.28675104276835867, Step Time 734 ms, ETA 0:55
# Step 380/445: Loss (avg) 0.26737923786765383, Step Time 731 ms, ETA 0:47
# Step 390/445: Loss (avg) 0.2703931765737255, Step Time 732 ms, ETA 0:40
# Step 400/445: Loss (avg) 0.23758410004113284, Step Time 736 ms, ETA 0:33
# Step 410/445: Loss (avg) 0.18577863493145888, Step Time 733 ms, ETA 0:25
# Step 420/445: Loss (avg) 0.28724665165401253, Step Time 735 ms, ETA 0:18
# Step 430/445: Loss (avg) 0.22558977546586229, Step Time 725 ms, ETA 0:10
# Step 440/445: Loss (avg) 0.25789893070162695, Step Time 737 ms, ETA 0:3
# Step 10/398: Loss (avg) 0.4398362358088923, Step Time 236 ms, ETA 1:31
# Step 20/398: Loss (avg) 0.5677616498985255, Step Time 239 ms, ETA 1:30
# Step 30/398: Loss (avg) 0.5449829026902183, Step Time 237 ms, ETA 1:27
# Step 40/398: Loss (avg) 0.6245595696630423, Step Time 236 ms, ETA 1:24
# Step 50/398: Loss (avg) 0.5394756626100129, Step Time 237 ms, ETA 1:22
# Step 60/398: Loss (avg) 0.5809272692959055, Step Time 237 ms, ETA 1:20
# Step 70/398: Loss (avg) 0.5652013999515608, Step Time 237 ms, ETA 1:17
# Step 80/398: Loss (avg) 0.6203528204079082, Step Time 237 ms, ETA 1:15
# Step 90/398: Loss (avg) 0.5691459020033527, Step Time 237 ms, ETA 1:12
# Step 100/398: Loss (avg) 0.489653300241609, Step Time 236 ms, ETA 1:10
# Step 110/398: Loss (avg) 0.5830901445749882, Step Time 236 ms, ETA 1:7
# Step 120/398: Loss (avg) 0.6069853501198432, Step Time 237 ms, ETA 1:5
# Step 130/398: Loss (avg) 0.6104233247533177, Step Time 238 ms, ETA 1:3
# Step 140/398: Loss (avg) 0.5722492139086253, Step Time 237 ms, ETA 1:1
# Step 150/398: Loss (avg) 0.5977234468036406, Step Time 236 ms, ETA 0:58
# Step 160/398: Loss (avg) 0.5443759131505341, Step Time 237 ms, ETA 0:56
# Step 170/398: Loss (avg) 0.5944244203072699, Step Time 237 ms, ETA 0:54
# Step 180/398: Loss (avg) 0.5551772941535082, Step Time 236 ms, ETA 0:51
# Step 190/398: Loss (avg) 0.5325874670619062, Step Time 237 ms, ETA 0:49
# Step 200/398: Loss (avg) 0.6025150898085965, Step Time 238 ms, ETA 0:47
# Step 210/398: Loss (avg) 0.4364022143032642, Step Time 236 ms, ETA 0:44
# Step 220/398: Loss (avg) 0.4299536957641353, Step Time 237 ms, ETA 0:42
# Step 230/398: Loss (avg) 0.6950631906078646, Step Time 237 ms, ETA 0:39
# Step 240/398: Loss (avg) 0.606960180412358, Step Time 236 ms, ETA 0:37
# Step 250/398: Loss (avg) 0.6042260533660656, Step Time 236 ms, ETA 0:34
# Step 260/398: Loss (avg) 0.740885616124693, Step Time 237 ms, ETA 0:32
# Step 270/398: Loss (avg) 0.6205451460225894, Step Time 237 ms, ETA 0:30
# Step 280/398: Loss (avg) 0.6316468360308322, Step Time 237 ms, ETA 0:27
# Step 290/398: Loss (avg) 0.6119231396453885, Step Time 237 ms, ETA 0:25
# Step 300/398: Loss (avg) 0.5843489030153542, Step Time 237 ms, ETA 0:23
# Step 310/398: Loss (avg) 0.512395675881887, Step Time 237 ms, ETA 0:20
# Step 320/398: Loss (avg) 0.652405866253654, Step Time 235 ms, ETA 0:18
# Step 330/398: Loss (avg) 0.5469048120934408, Step Time 236 ms, ETA 0:16
# Step 340/398: Loss (avg) 0.42679203572468344, Step Time 237 ms, ETA 0:13
# Step 350/398: Loss (avg) 0.5358762918152249, Step Time 237 ms, ETA 0:11
# Step 360/398: Loss (avg) 0.4923796156772687, Step Time 236 ms, ETA 0:8
# Step 370/398: Loss (avg) 0.5883931548896228, Step Time 237 ms, ETA 0:6
# Step 380/398: Loss (avg) 0.5362669341560163, Step Time 237 ms, ETA 0:4
# Step 390/398: Loss (avg) 0.6652388005417754, Step Time 237 ms, ETA 0:1
# Metrics for test set:
#    accuracy        f1  precision    recall  specificity     auroc     aupr  \
# 0  0.776589  0.796328   0.756816  0.840194     0.707733  0.773963  0.84004
#
#              confusion_matrix
# 0  [[1080, 446], [264, 1388]]
# Step 10/445: Loss (avg) 0.4489559223686076, Step Time 722 ms, ETA 5:14
# Step 20/445: Loss (avg) 0.6011335756793375, Step Time 725 ms, ETA 5:8
# Step 30/445: Loss (avg) 0.6504360411666127, Step Time 727 ms, ETA 5:1
# Step 40/445: Loss (avg) 0.6549807287933348, Step Time 728 ms, ETA 4:54
# Step 50/445: Loss (avg) 0.6368144177405475, Step Time 730 ms, ETA 4:48
# Step 60/445: Loss (avg) 0.6050141515441432, Step Time 727 ms, ETA 4:39
# Step 70/445: Loss (avg) 0.5491426065368139, Step Time 730 ms, ETA 4:33
# Step 80/445: Loss (avg) 0.5325819240456359, Step Time 731 ms, ETA 4:26
# Step 90/445: Loss (avg) 0.5360999896272438, Step Time 731 ms, ETA 4:19
# Step 100/445: Loss (avg) 0.5027399299683695, Step Time 733 ms, ETA 4:12
# Step 110/445: Loss (avg) 0.48292424253470717, Step Time 733 ms, ETA 4:5
# Step 120/445: Loss (avg) 0.45026073418802476, Step Time 733 ms, ETA 3:58
# Step 130/445: Loss (avg) 0.4259048993262591, Step Time 733 ms, ETA 3:50
# Step 140/445: Loss (avg) 0.42451235238900714, Step Time 733 ms, ETA 3:43
# Step 150/445: Loss (avg) 0.40991153786334733, Step Time 733 ms, ETA 3:36
# Step 160/445: Loss (avg) 0.35531476350142505, Step Time 732 ms, ETA 3:28
# Step 170/445: Loss (avg) 0.347995073532345, Step Time 733 ms, ETA 3:21
# Step 180/445: Loss (avg) 0.3360794015668878, Step Time 732 ms, ETA 3:13
# Step 190/445: Loss (avg) 0.3969607921275436, Step Time 734 ms, ETA 3:7
# Step 200/445: Loss (avg) 0.3528910438480755, Step Time 733 ms, ETA 2:59
# Step 210/445: Loss (avg) 0.34187078723251946, Step Time 734 ms, ETA 2:52
# Step 220/445: Loss (avg) 0.3159691314759653, Step Time 733 ms, ETA 2:44
# Step 230/445: Loss (avg) 0.3127837634255357, Step Time 730 ms, ETA 2:36
# Step 240/445: Loss (avg) 0.34313025870401576, Step Time 732 ms, ETA 2:30
# Step 250/445: Loss (avg) 0.30780028771518675, Step Time 734 ms, ETA 2:23
# Step 260/445: Loss (avg) 0.2934708197167519, Step Time 735 ms, ETA 2:15
# Step 270/445: Loss (avg) 0.30163705724488793, Step Time 736 ms, ETA 2:8
# Step 280/445: Loss (avg) 0.2750493873699979, Step Time 732 ms, ETA 2:0
# Step 290/445: Loss (avg) 0.30449063335930043, Step Time 733 ms, ETA 1:53
# Step 300/445: Loss (avg) 0.250715343326377, Step Time 727 ms, ETA 1:45
# Step 310/445: Loss (avg) 0.2889213057136938, Step Time 733 ms, ETA 1:38
# Step 320/445: Loss (avg) 0.26406173827379115, Step Time 734 ms, ETA 1:31
# Step 330/445: Loss (avg) 0.23434062321417526, Step Time 724 ms, ETA 1:23
# Step 340/445: Loss (avg) 0.21434623550563606, Step Time 735 ms, ETA 1:17
# Step 350/445: Loss (avg) 0.2552105287457634, Step Time 737 ms, ETA 1:10
# Step 360/445: Loss (avg) 0.308969280949782, Step Time 733 ms, ETA 1:2
# Step 370/445: Loss (avg) 0.2534005747377361, Step Time 733 ms, ETA 0:54
# Step 380/445: Loss (avg) 0.25961969955879355, Step Time 735 ms, ETA 0:47
# Step 390/445: Loss (avg) 0.24579638862167033, Step Time 738 ms, ETA 0:40
# Step 400/445: Loss (avg) 0.2129501930912437, Step Time 737 ms, ETA 0:33
# Step 410/445: Loss (avg) 0.2876488693576478, Step Time 732 ms, ETA 0:25
# Step 420/445: Loss (avg) 0.3036191771274381, Step Time 734 ms, ETA 0:18
# Step 430/445: Loss (avg) 0.22777861220137188, Step Time 734 ms, ETA 0:11
# Step 440/445: Loss (avg) 0.27575078590763497, Step Time 739 ms, ETA 0:3
# Step 10/398: Loss (avg) 0.3450306987379592, Step Time 238 ms, ETA 1:32
# Step 20/398: Loss (avg) 0.4945344181441493, Step Time 237 ms, ETA 1:29
# Step 30/398: Loss (avg) 0.4438942451711246, Step Time 237 ms, ETA 1:27
# Step 40/398: Loss (avg) 0.4813941740848493, Step Time 236 ms, ETA 1:24
# Step 50/398: Loss (avg) 0.49447738913493244, Step Time 235 ms, ETA 1:21
# Step 60/398: Loss (avg) 0.46820262467283974, Step Time 237 ms, ETA 1:20
# Step 70/398: Loss (avg) 0.5701222988735968, Step Time 238 ms, ETA 1:18
# Step 80/398: Loss (avg) 0.5289774182837623, Step Time 239 ms, ETA 1:16
# Step 90/398: Loss (avg) 0.6129184468626088, Step Time 236 ms, ETA 1:12
# Step 100/398: Loss (avg) 0.46659813155388286, Step Time 237 ms, ETA 1:10
# Step 110/398: Loss (avg) 0.6144407588566182, Step Time 236 ms, ETA 1:7
# Step 120/398: Loss (avg) 0.520893587966804, Step Time 236 ms, ETA 1:5
# Step 130/398: Loss (avg) 0.6273588706320542, Step Time 237 ms, ETA 1:3
# Step 140/398: Loss (avg) 0.5877311417943667, Step Time 237 ms, ETA 1:1
# Step 150/398: Loss (avg) 0.5379188388443804, Step Time 236 ms, ETA 0:58
# Step 160/398: Loss (avg) 0.5609804647940728, Step Time 236 ms, ETA 0:56
# Step 170/398: Loss (avg) 0.6136900328138436, Step Time 237 ms, ETA 0:54
# Step 180/398: Loss (avg) 0.5382228961313817, Step Time 237 ms, ETA 0:51
# Step 190/398: Loss (avg) 0.6383410021316661, Step Time 236 ms, ETA 0:49
# Step 200/398: Loss (avg) 0.5991651838820726, Step Time 236 ms, ETA 0:46
# Step 210/398: Loss (avg) 0.5729598989609388, Step Time 235 ms, ETA 0:44
# Step 220/398: Loss (avg) 0.52983197555937, Step Time 236 ms, ETA 0:42
# Step 230/398: Loss (avg) 0.6263483155501979, Step Time 238 ms, ETA 0:39
# Step 240/398: Loss (avg) 0.4995829242168884, Step Time 237 ms, ETA 0:37
# Step 250/398: Loss (avg) 0.48455911616845826, Step Time 236 ms, ETA 0:34
# Step 260/398: Loss (avg) 0.4925663389518254, Step Time 236 ms, ETA 0:32
# Step 270/398: Loss (avg) 0.5264173899341326, Step Time 236 ms, ETA 0:30
# Step 280/398: Loss (avg) 0.4356354135027033, Step Time 237 ms, ETA 0:27
# Step 290/398: Loss (avg) 0.5107796504182691, Step Time 238 ms, ETA 0:25
# Step 300/398: Loss (avg) 0.711438462407788, Step Time 237 ms, ETA 0:23
# Step 310/398: Loss (avg) 0.6017260317980364, Step Time 236 ms, ETA 0:20
# Step 320/398: Loss (avg) 0.5945420865253992, Step Time 237 ms, ETA 0:18
# Step 330/398: Loss (avg) 0.5590085090232113, Step Time 236 ms, ETA 0:16
# Step 340/398: Loss (avg) 0.4946927513870147, Step Time 236 ms, ETA 0:13
# Step 350/398: Loss (avg) 0.5434869018622501, Step Time 237 ms, ETA 0:11
# Step 360/398: Loss (avg) 0.629915802620799, Step Time 236 ms, ETA 0:8
# Step 370/398: Loss (avg) 0.5226825474521759, Step Time 237 ms, ETA 0:6
# Step 380/398: Loss (avg) 0.4877043464278898, Step Time 237 ms, ETA 0:4
# Step 390/398: Loss (avg) 0.457200414578556, Step Time 236 ms, ETA 0:1
# Metrics for test set:
#    accuracy        f1  precision   recall  specificity     auroc      aupr  \
# 0  0.792008  0.808239   0.776045  0.84322     0.736566  0.789893  0.850381
#
#              confusion_matrix
# 0  [[1124, 402], [259, 1393]]
# Step 10/445: Loss (avg) 0.4521496174372982, Step Time 722 ms, ETA 5:14
# Step 20/445: Loss (avg) 0.6056185452199826, Step Time 726 ms, ETA 5:8
# Step 30/445: Loss (avg) 0.6561764610009724, Step Time 727 ms, ETA 5:1
# Step 40/445: Loss (avg) 0.6627994578836378, Step Time 730 ms, ETA 4:55
# Step 50/445: Loss (avg) 0.6512217615760192, Step Time 725 ms, ETA 4:46
# Step 60/445: Loss (avg) 0.6222910776777235, Step Time 729 ms, ETA 4:40
# Step 70/445: Loss (avg) 0.5962173870487784, Step Time 728 ms, ETA 4:33
# Step 80/445: Loss (avg) 0.5580089984113055, Step Time 730 ms, ETA 4:26
# Step 90/445: Loss (avg) 0.5241869243109805, Step Time 731 ms, ETA 4:19
# Step 100/445: Loss (avg) 0.512991355171986, Step Time 731 ms, ETA 4:12
# Step 110/445: Loss (avg) 0.48850313399960876, Step Time 731 ms, ETA 4:4
# Step 120/445: Loss (avg) 0.43898154972741815, Step Time 733 ms, ETA 3:58
# Step 130/445: Loss (avg) 0.4479830725889514, Step Time 732 ms, ETA 3:50
# Step 140/445: Loss (avg) 0.43207319104955844, Step Time 735 ms, ETA 3:44
# Step 150/445: Loss (avg) 0.3646990517268328, Step Time 732 ms, ETA 3:35
# Step 160/445: Loss (avg) 0.42161269360983467, Step Time 733 ms, ETA 3:28
# Step 170/445: Loss (avg) 0.37394311911803557, Step Time 732 ms, ETA 3:21
# Step 180/445: Loss (avg) 0.3896379359161809, Step Time 734 ms, ETA 3:14
# Step 190/445: Loss (avg) 0.39099768268163937, Step Time 734 ms, ETA 3:7
# Step 200/445: Loss (avg) 0.3488371591849071, Step Time 734 ms, ETA 2:59
# Step 210/445: Loss (avg) 0.37599802188055487, Step Time 733 ms, ETA 2:52
# Step 220/445: Loss (avg) 0.33243020388367306, Step Time 734 ms, ETA 2:45
# Step 230/445: Loss (avg) 0.3210266318192738, Step Time 735 ms, ETA 2:38
# Step 240/445: Loss (avg) 0.3386448483459735, Step Time 732 ms, ETA 2:30
# Step 250/445: Loss (avg) 0.3068939324677605, Step Time 736 ms, ETA 2:23
# Step 260/445: Loss (avg) 0.3631622489047993, Step Time 734 ms, ETA 2:15
# Step 270/445: Loss (avg) 0.40047459788586515, Step Time 735 ms, ETA 2:8
# Step 280/445: Loss (avg) 0.36504775817615326, Step Time 735 ms, ETA 2:1
# Step 290/445: Loss (avg) 0.3569754353268365, Step Time 735 ms, ETA 1:53
# Step 300/445: Loss (avg) 0.34984145081635526, Step Time 734 ms, ETA 1:46
# Step 310/445: Loss (avg) 0.3906169254161793, Step Time 733 ms, ETA 1:38
# Step 320/445: Loss (avg) 0.3406647969371863, Step Time 735 ms, ETA 1:31
# Step 330/445: Loss (avg) 0.3078366702839197, Step Time 733 ms, ETA 1:24
# Step 340/445: Loss (avg) 0.28934370582553465, Step Time 737 ms, ETA 1:17
# Step 350/445: Loss (avg) 0.2352149804816179, Step Time 734 ms, ETA 1:9
# Step 360/445: Loss (avg) 0.2259889261448586, Step Time 735 ms, ETA 1:2
# Step 370/445: Loss (avg) 0.2611744343573632, Step Time 736 ms, ETA 0:55
# Step 380/445: Loss (avg) 0.31469822576409634, Step Time 734 ms, ETA 0:47
# Step 390/445: Loss (avg) 0.3184688582703079, Step Time 734 ms, ETA 0:40
# Step 400/445: Loss (avg) 0.2696243189088884, Step Time 733 ms, ETA 0:32
# Step 410/445: Loss (avg) 0.3034881106501449, Step Time 734 ms, ETA 0:25
# Step 420/445: Loss (avg) 0.31201666256197297, Step Time 733 ms, ETA 0:18
# Step 430/445: Loss (avg) 0.29177389402645837, Step Time 734 ms, ETA 0:11
# Step 440/445: Loss (avg) 0.281549207819896, Step Time 734 ms, ETA 0:3
# Step 10/398: Loss (avg) 0.41125160444084946, Step Time 239 ms, ETA 1:32
# Step 20/398: Loss (avg) 0.4148120910229214, Step Time 238 ms, ETA 1:29
# Step 30/398: Loss (avg) 0.5849983714256547, Step Time 236 ms, ETA 1:26
# Step 40/398: Loss (avg) 0.6297578982002603, Step Time 238 ms, ETA 1:25
# Step 50/398: Loss (avg) 0.599159976322991, Step Time 237 ms, ETA 1:22
# Step 60/398: Loss (avg) 0.555843191097298, Step Time 237 ms, ETA 1:20
# Step 70/398: Loss (avg) 0.5249890549905389, Step Time 237 ms, ETA 1:17
# Step 80/398: Loss (avg) 0.5866638490307525, Step Time 238 ms, ETA 1:15
# Step 90/398: Loss (avg) 0.5274703517159323, Step Time 237 ms, ETA 1:12
# Step 100/398: Loss (avg) 0.6149810938565423, Step Time 236 ms, ETA 1:10
# Step 110/398: Loss (avg) 0.5319584973562969, Step Time 236 ms, ETA 1:7
# Step 120/398: Loss (avg) 0.5975308798076191, Step Time 236 ms, ETA 1:5
# Step 130/398: Loss (avg) 0.5842498764343486, Step Time 237 ms, ETA 1:3
# Step 140/398: Loss (avg) 0.5204858540506977, Step Time 238 ms, ETA 1:1
# Step 150/398: Loss (avg) 0.5072443890571406, Step Time 235 ms, ETA 0:58
# Step 160/398: Loss (avg) 0.46191482538698797, Step Time 236 ms, ETA 0:56
# Step 170/398: Loss (avg) 0.4789386782563282, Step Time 237 ms, ETA 0:54
# Step 180/398: Loss (avg) 0.421750886192676, Step Time 236 ms, ETA 0:51
# Step 190/398: Loss (avg) 0.5395476781251689, Step Time 236 ms, ETA 0:49
# Step 200/398: Loss (avg) 0.42718410885585784, Step Time 239 ms, ETA 0:47
# Step 210/398: Loss (avg) 0.5101167260656168, Step Time 236 ms, ETA 0:44
# Step 220/398: Loss (avg) 0.41703055112878584, Step Time 236 ms, ETA 0:42
# Step 230/398: Loss (avg) 0.5463824161800067, Step Time 237 ms, ETA 0:39
# Step 240/398: Loss (avg) 0.516405360472701, Step Time 237 ms, ETA 0:37
# Step 250/398: Loss (avg) 0.5485880976593328, Step Time 236 ms, ETA 0:34
# Step 260/398: Loss (avg) 0.5832083466604354, Step Time 237 ms, ETA 0:32
# Step 270/398: Loss (avg) 0.5416782346152327, Step Time 237 ms, ETA 0:30
# Step 280/398: Loss (avg) 0.529953740046555, Step Time 237 ms, ETA 0:27
# Step 290/398: Loss (avg) 0.6754517206684127, Step Time 236 ms, ETA 0:25
# Step 300/398: Loss (avg) 0.6241365430701971, Step Time 237 ms, ETA 0:23
# Step 310/398: Loss (avg) 0.5367057821159092, Step Time 236 ms, ETA 0:20
# Step 320/398: Loss (avg) 0.6060903497751391, Step Time 237 ms, ETA 0:18
# Step 330/398: Loss (avg) 0.4992520381340377, Step Time 237 ms, ETA 0:16
# Step 340/398: Loss (avg) 0.47244066164543075, Step Time 236 ms, ETA 0:13
# Step 350/398: Loss (avg) 0.5462375949941474, Step Time 236 ms, ETA 0:11
# Step 360/398: Loss (avg) 0.6259413867768856, Step Time 236 ms, ETA 0:8
# Step 370/398: Loss (avg) 0.6084199255529676, Step Time 237 ms, ETA 0:6
# Step 380/398: Loss (avg) 0.576776076517628, Step Time 237 ms, ETA 0:4
# Step 390/398: Loss (avg) 0.5215314027329483, Step Time 237 ms, ETA 0:1
# Metrics for test set:
#    accuracy        f1  precision    recall  specificity     auroc      aupr  \
# 0   0.78068  0.805144   0.748052  0.871671     0.682176  0.776923  0.843216
#
#              confusion_matrix
# 0  [[1041, 485], [212, 1440]]
# Step 10/445: Loss (avg) 0.45255670499813244, Step Time 725 ms, ETA 5:15
# Step 20/445: Loss (avg) 0.5981246967603213, Step Time 725 ms, ETA 5:8
# Step 30/445: Loss (avg) 0.6738641128284342, Step Time 725 ms, ETA 5:0
# Step 40/445: Loss (avg) 0.6843311978670117, Step Time 727 ms, ETA 4:54
# Step 50/445: Loss (avg) 0.6642350327159141, Step Time 728 ms, ETA 4:47
# Step 60/445: Loss (avg) 0.6349406803196112, Step Time 730 ms, ETA 4:41
# Step 70/445: Loss (avg) 0.6047395009774628, Step Time 731 ms, ETA 4:34
# Step 80/445: Loss (avg) 0.5839174165692375, Step Time 732 ms, ETA 4:27
# Step 90/445: Loss (avg) 0.5375354014284661, Step Time 730 ms, ETA 4:19
# Step 100/445: Loss (avg) 0.5138505389330872, Step Time 732 ms, ETA 4:12
# Step 110/445: Loss (avg) 0.49907720702649405, Step Time 733 ms, ETA 4:5
# Step 120/445: Loss (avg) 0.47318098602682906, Step Time 733 ms, ETA 3:58
# Step 130/445: Loss (avg) 0.45930518350612143, Step Time 725 ms, ETA 3:48
# Step 140/445: Loss (avg) 0.4459770315755648, Step Time 735 ms, ETA 3:44
# Step 150/445: Loss (avg) 0.4220570591337049, Step Time 735 ms, ETA 3:36
# Step 160/445: Loss (avg) 0.4040529727000168, Step Time 735 ms, ETA 3:29
# Step 170/445: Loss (avg) 0.3862465121560252, Step Time 734 ms, ETA 3:21
# Step 180/445: Loss (avg) 0.35796841933257384, Step Time 728 ms, ETA 3:12
# Step 190/445: Loss (avg) 0.3390581666544615, Step Time 732 ms, ETA 3:6
# Step 200/445: Loss (avg) 0.37265300590223993, Step Time 734 ms, ETA 2:59
# Step 210/445: Loss (avg) 0.3847629322221112, Step Time 732 ms, ETA 2:52
# Step 220/445: Loss (avg) 0.34110937831871524, Step Time 736 ms, ETA 2:45
# Step 230/445: Loss (avg) 0.354086255445768, Step Time 726 ms, ETA 2:36
# Step 240/445: Loss (avg) 0.3532577084809288, Step Time 734 ms, ETA 2:30
# Step 250/445: Loss (avg) 0.33106236327259025, Step Time 734 ms, ETA 2:23
# Step 260/445: Loss (avg) 0.2860901667385188, Step Time 735 ms, ETA 2:15
# Step 270/445: Loss (avg) 0.3235645165244488, Step Time 733 ms, ETA 2:8
# Step 280/445: Loss (avg) 0.23884138056799248, Step Time 735 ms, ETA 2:1
# Step 290/445: Loss (avg) 0.27048967253132983, Step Time 733 ms, ETA 1:53
# Step 300/445: Loss (avg) 0.2930629766303924, Step Time 735 ms, ETA 1:46
# Step 310/445: Loss (avg) 0.3218998431705183, Step Time 734 ms, ETA 1:39
# Step 320/445: Loss (avg) 0.2579330660183523, Step Time 732 ms, ETA 1:31
# Step 330/445: Loss (avg) 0.244112103981326, Step Time 733 ms, ETA 1:24
# Step 340/445: Loss (avg) 0.21334453194104916, Step Time 737 ms, ETA 1:17
# Step 350/445: Loss (avg) 0.3511782184842621, Step Time 735 ms, ETA 1:9
# Step 360/445: Loss (avg) 0.3297355166802185, Step Time 737 ms, ETA 1:2
# Step 370/445: Loss (avg) 0.27510578668664265, Step Time 733 ms, ETA 0:54
# Step 380/445: Loss (avg) 0.2653706910384486, Step Time 736 ms, ETA 0:47
# Step 390/445: Loss (avg) 0.24075139587902733, Step Time 735 ms, ETA 0:40
# Step 400/445: Loss (avg) 0.22555496257184338, Step Time 735 ms, ETA 0:33
# Step 410/445: Loss (avg) 0.19587913895416315, Step Time 735 ms, ETA 0:25
# Step 420/445: Loss (avg) 0.2688344884031448, Step Time 727 ms, ETA 0:18
# Step 430/445: Loss (avg) 0.3193322659964438, Step Time 735 ms, ETA 0:11
# Step 440/445: Loss (avg) 0.2986585837989309, Step Time 734 ms, ETA 0:3
# Step 10/398: Loss (avg) 0.39569184208138414, Step Time 235 ms, ETA 1:31
# Step 20/398: Loss (avg) 0.46048326799841033, Step Time 236 ms, ETA 1:29
# Step 30/398: Loss (avg) 0.4659838201015696, Step Time 237 ms, ETA 1:27
# Step 40/398: Loss (avg) 0.4042221225466039, Step Time 238 ms, ETA 1:25
# Step 50/398: Loss (avg) 0.4948002129861793, Step Time 237 ms, ETA 1:22
# Step 60/398: Loss (avg) 0.7174552434733322, Step Time 236 ms, ETA 1:19
# Step 70/398: Loss (avg) 0.5416339484402966, Step Time 236 ms, ETA 1:17
# Step 80/398: Loss (avg) 0.57825428080854, Step Time 237 ms, ETA 1:15
# Step 90/398: Loss (avg) 0.6024389643636956, Step Time 236 ms, ETA 1:12
# Step 100/398: Loss (avg) 0.6159379131538258, Step Time 237 ms, ETA 1:10
# Step 110/398: Loss (avg) 0.5360847971554703, Step Time 237 ms, ETA 1:8
# Step 120/398: Loss (avg) 0.6723830003564452, Step Time 236 ms, ETA 1:5
# Step 130/398: Loss (avg) 0.5921893680638672, Step Time 237 ms, ETA 1:3
# Step 140/398: Loss (avg) 0.6235563695852693, Step Time 237 ms, ETA 1:1
# Step 150/398: Loss (avg) 0.5161847322268618, Step Time 236 ms, ETA 0:58
# Step 160/398: Loss (avg) 0.5029313430931199, Step Time 238 ms, ETA 0:56
# Step 170/398: Loss (avg) 0.48906307284945916, Step Time 236 ms, ETA 0:53
# Step 180/398: Loss (avg) 0.582133655794857, Step Time 236 ms, ETA 0:51
# Step 190/398: Loss (avg) 0.48899540071342884, Step Time 236 ms, ETA 0:49
# Step 200/398: Loss (avg) 0.4961480225804315, Step Time 237 ms, ETA 0:46
# ...
# Step 380/445: Loss (avg) 0.26156519005321277, Step Time 735 ms, ETA 0:47
# Step 390/445: Loss (avg) 0.23367408957640004, Step Time 736 ms, ETA 0:40
# Step 400/445: Loss (avg) 0.24257107928512686, Step Time 735 ms, ETA 0:33
# Step 410/445: Loss (avg) 0.25128420090810966, Step Time 737 ms, ETA 0:25
# Step 420/445: Loss (avg) 0.3362709967331227, Step Time 736 ms, ETA 0:18
# Step 430/445: Loss (avg) 0.2802468777410925, Step Time 735 ms, ETA 0:11
# Step 440/445: Loss (avg) 0.2503383360387247, Step Time 727 ms, ETA 0:3
# Step 10/398: Loss (avg) 0.3332941380053782, Step Time 237 ms, ETA 1:31
# Step 20/398: Loss (avg) 0.4750687386983318, Step Time 237 ms, ETA 1:29
# Step 30/398: Loss (avg) 0.4443268595756889, Step Time 235 ms, ETA 1:26
# Step 40/398: Loss (avg) 0.5444463390289889, Step Time 236 ms, ETA 1:24
# Step 50/398: Loss (avg) 0.5475638586322502, Step Time 237 ms, ETA 1:22
# Step 60/398: Loss (avg) 0.5866270585228566, Step Time 239 ms, ETA 1:20
# Step 70/398: Loss (avg) 0.6808654631551865, Step Time 237 ms, ETA 1:17
# Step 80/398: Loss (avg) 0.6144864774665066, Step Time 236 ms, ETA 1:15
# Step 90/398: Loss (avg) 0.7118738088706686, Step Time 237 ms, ETA 1:12
# Step 100/398: Loss (avg) 0.6023687197325444, Step Time 237 ms, ETA 1:10
# Step 110/398: Loss (avg) 0.6319445243174759, Step Time 238 ms, ETA 1:8
# Step 120/398: Loss (avg) 0.5885217543778628, Step Time 236 ms, ETA 1:5
# Step 130/398: Loss (avg) 0.6706651656197822, Step Time 236 ms, ETA 1:3
# Step 140/398: Loss (avg) 0.5961110607317797, Step Time 236 ms, ETA 1:0
# Step 150/398: Loss (avg) 0.6205100606920723, Step Time 237 ms, ETA 0:58
# Step 160/398: Loss (avg) 0.5519450254364949, Step Time 238 ms, ETA 0:56
# Step 170/398: Loss (avg) 0.5025137123856117, Step Time 236 ms, ETA 0:53
# Step 180/398: Loss (avg) 0.6248632131298644, Step Time 237 ms, ETA 0:51
# Step 190/398: Loss (avg) 0.6880038084300346, Step Time 236 ms, ETA 0:49
# Step 200/398: Loss (avg) 0.613690849768752, Step Time 237 ms, ETA 0:46
# Step 210/398: Loss (avg) 0.6181633807556914, Step Time 237 ms, ETA 0:44
# Step 220/398: Loss (avg) 0.5341910094259607, Step Time 238 ms, ETA 0:42
# Step 230/398: Loss (avg) 0.7043031572254154, Step Time 238 ms, ETA 0:39
# Step 240/398: Loss (avg) 0.6987328290991397, Step Time 236 ms, ETA 0:37
# Step 250/398: Loss (avg) 0.6830479835556412, Step Time 237 ms, ETA 0:35
# Step 260/398: Loss (avg) 0.6061704011884873, Step Time 237 ms, ETA 0:32
# Step 270/398: Loss (avg) 0.6170571677065506, Step Time 237 ms, ETA 0:30
# Step 280/398: Loss (avg) 0.5456954201193367, Step Time 238 ms, ETA 0:28
# Step 290/398: Loss (avg) 0.5041335710584877, Step Time 237 ms, ETA 0:25
# Step 300/398: Loss (avg) 0.5646771312729544, Step Time 236 ms, ETA 0:23
# Step 310/398: Loss (avg) 0.6095240173805169, Step Time 236 ms, ETA 0:20
# Step 320/398: Loss (avg) 0.5619755633172113, Step Time 237 ms, ETA 0:18
# Step 330/398: Loss (avg) 0.6609384700184598, Step Time 236 ms, ETA 0:16
# Step 340/398: Loss (avg) 0.6503703866082005, Step Time 238 ms, ETA 0:13
# Step 350/398: Loss (avg) 0.6949070660163096, Step Time 238 ms, ETA 0:11
# Step 360/398: Loss (avg) 0.594214141365358, Step Time 236 ms, ETA 0:8
# Step 370/398: Loss (avg) 0.6378488588874255, Step Time 237 ms, ETA 0:6
# Step 380/398: Loss (avg) 0.5842461143516013, Step Time 237 ms, ETA 0:4
# Step 390/398: Loss (avg) 0.5453372713569821, Step Time 236 ms, ETA 0:1
# Metrics for test set:
#    accuracy        f1  precision    recall  specificity     auroc      aupr  \
# 0  0.722467  0.760065   0.690217  0.845642     0.589122  0.717382  0.808049
#
#             confusion_matrix
# 0  [[899, 627], [255, 1397]]
# Step 10/445: Loss (avg) 0.4501429058854779, Step Time 722 ms, ETA 5:14
# Step 20/445: Loss (avg) 0.608203651091796, Step Time 725 ms, ETA 5:8
# Step 30/445: Loss (avg) 0.6535910427317285, Step Time 729 ms, ETA 5:2
# Step 40/445: Loss (avg) 0.6603335120661178, Step Time 728 ms, ETA 4:54
# Step 50/445: Loss (avg) 0.6331142379380034, Step Time 729 ms, ETA 4:47
# Step 60/445: Loss (avg) 0.6006504146800951, Step Time 722 ms, ETA 4:37
# Step 70/445: Loss (avg) 0.5648040723656214, Step Time 722 ms, ETA 4:30
# Step 80/445: Loss (avg) 0.5247381276215248, Step Time 732 ms, ETA 4:27
# Step 90/445: Loss (avg) 0.483680115792518, Step Time 733 ms, ETA 4:20
# Step 100/445: Loss (avg) 0.4481711728539584, Step Time 732 ms, ETA 4:12
# Step 110/445: Loss (avg) 0.4615815642950878, Step Time 732 ms, ETA 4:5
# Step 120/445: Loss (avg) 0.4578710545306781, Step Time 733 ms, ETA 3:58
# Step 130/445: Loss (avg) 0.4280183698987136, Step Time 730 ms, ETA 3:49
# Step 140/445: Loss (avg) 0.42315661239736657, Step Time 731 ms, ETA 3:42
# Step 150/445: Loss (avg) 0.3918363696739797, Step Time 734 ms, ETA 3:36
# Step 160/445: Loss (avg) 0.3927876908572, Step Time 731 ms, ETA 3:28
# Step 170/445: Loss (avg) 0.39241153969521503, Step Time 735 ms, ETA 3:22
# Step 180/445: Loss (avg) 0.4196330291998965, Step Time 733 ms, ETA 3:14
# Step 190/445: Loss (avg) 0.33660142530622544, Step Time 735 ms, ETA 3:7
# Step 200/445: Loss (avg) 0.3414646765163856, Step Time 731 ms, ETA 2:59
# Step 210/445: Loss (avg) 0.32093050019352437, Step Time 732 ms, ETA 2:52
# Step 220/445: Loss (avg) 0.30150719203178467, Step Time 733 ms, ETA 2:44
# Step 230/445: Loss (avg) 0.32643522515683315, Step Time 733 ms, ETA 2:37
# Step 240/445: Loss (avg) 0.2785104429696094, Step Time 732 ms, ETA 2:30
# Step 250/445: Loss (avg) 0.29936079018619055, Step Time 737 ms, ETA 2:23
# Step 260/445: Loss (avg) 0.29388075910696965, Step Time 734 ms, ETA 2:15
# Step 270/445: Loss (avg) 0.3059275051023531, Step Time 733 ms, ETA 2:8
# Step 280/445: Loss (avg) 0.27107797225861063, Step Time 734 ms, ETA 2:1
# Step 290/445: Loss (avg) 0.28136062589363386, Step Time 734 ms, ETA 1:53
# Step 300/445: Loss (avg) 0.26930956781122267, Step Time 735 ms, ETA 1:46
# Step 310/445: Loss (avg) 0.2716529253305674, Step Time 735 ms, ETA 1:39
# Step 320/445: Loss (avg) 0.3176434061621903, Step Time 733 ms, ETA 1:31
# Step 330/445: Loss (avg) 0.3112158987336972, Step Time 733 ms, ETA 1:24
# Step 340/445: Loss (avg) 0.30297397380533947, Step Time 734 ms, ETA 1:17
# Step 350/445: Loss (avg) 0.28625339804308614, Step Time 734 ms, ETA 1:9
# Step 360/445: Loss (avg) 0.2470945648596309, Step Time 734 ms, ETA 1:2
# Step 370/445: Loss (avg) 0.2777824480216276, Step Time 735 ms, ETA 0:55
# Step 380/445: Loss (avg) 0.3339265156209007, Step Time 736 ms, ETA 0:47
# Step 390/445: Loss (avg) 0.3358884558402425, Step Time 734 ms, ETA 0:40
# Step 400/445: Loss (avg) 0.32177724639239746, Step Time 736 ms, ETA 0:33
# Step 410/445: Loss (avg) 0.300417693284111, Step Time 736 ms, ETA 0:25
# Step 420/445: Loss (avg) 0.23106543285194053, Step Time 734 ms, ETA 0:18
# Step 430/445: Loss (avg) 0.22817689958687964, Step Time 733 ms, ETA 0:10
# Step 440/445: Loss (avg) 0.22048036526414228, Step Time 735 ms, ETA 0:3
# Step 10/398: Loss (avg) 0.3528461736774075, Step Time 235 ms, ETA 1:31
# Step 20/398: Loss (avg) 0.4778729281012588, Step Time 236 ms, ETA 1:29
# Step 30/398: Loss (avg) 0.5683696435010538, Step Time 236 ms, ETA 1:26
# Step 40/398: Loss (avg) 0.6126965568110941, Step Time 239 ms, ETA 1:25
# Step 50/398: Loss (avg) 0.5415294216502076, Step Time 236 ms, ETA 1:22
# Step 60/398: Loss (avg) 0.5532121622306739, Step Time 236 ms, ETA 1:19
# Step 70/398: Loss (avg) 0.6047014056525375, Step Time 236 ms, ETA 1:17
# Step 80/398: Loss (avg) 0.49547078352306717, Step Time 236 ms, ETA 1:15
# Step 90/398: Loss (avg) 0.5896978604579792, Step Time 237 ms, ETA 1:12
# Step 100/398: Loss (avg) 0.5301748766104158, Step Time 237 ms, ETA 1:10
# Step 110/398: Loss (avg) 0.5876771058822616, Step Time 237 ms, ETA 1:8
# Step 120/398: Loss (avg) 0.47378992088600125, Step Time 236 ms, ETA 1:5
# Step 130/398: Loss (avg) 0.5333888687396418, Step Time 236 ms, ETA 1:3
# Step 140/398: Loss (avg) 0.5326842398302839, Step Time 236 ms, ETA 1:0
# Step 150/398: Loss (avg) 0.5100023494179207, Step Time 236 ms, ETA 0:58
# Step 160/398: Loss (avg) 0.5689135743177348, Step Time 238 ms, ETA 0:56
# Step 170/398: Loss (avg) 0.48812621721001725, Step Time 236 ms, ETA 0:53
# Step 180/398: Loss (avg) 0.42726248533752254, Step Time 236 ms, ETA 0:51
# Step 190/398: Loss (avg) 0.4940076218901357, Step Time 236 ms, ETA 0:49
# Step 200/398: Loss (avg) 0.5017369251838362, Step Time 236 ms, ETA 0:46
# Step 210/398: Loss (avg) 0.5214786408119297, Step Time 237 ms, ETA 0:44
# Step 220/398: Loss (avg) 0.5183289478700833, Step Time 237 ms, ETA 0:42
# Step 230/398: Loss (avg) 0.646033613179762, Step Time 236 ms, ETA 0:39
# Step 240/398: Loss (avg) 0.6604309418896303, Step Time 237 ms, ETA 0:37
# Step 250/398: Loss (avg) 0.6365335421118476, Step Time 237 ms, ETA 0:35
# Step 260/398: Loss (avg) 0.6110620643379042, Step Time 236 ms, ETA 0:32
# Step 270/398: Loss (avg) 0.6256537036373269, Step Time 238 ms, ETA 0:30
# Step 280/398: Loss (avg) 0.5754136718463023, Step Time 237 ms, ETA 0:27
# Step 290/398: Loss (avg) 0.3772253458401265, Step Time 235 ms, ETA 0:25
# Step 300/398: Loss (avg) 0.5002420665911016, Step Time 236 ms, ETA 0:23
# Step 310/398: Loss (avg) 0.5616613008459967, Step Time 237 ms, ETA 0:20
# Step 320/398: Loss (avg) 0.5907356722925388, Step Time 237 ms, ETA 0:18
# Step 330/398: Loss (avg) 0.6030405858485666, Step Time 237 ms, ETA 0:16
# Step 340/398: Loss (avg) 0.5696402479824866, Step Time 236 ms, ETA 0:13
# Step 350/398: Loss (avg) 0.6664590968778139, Step Time 237 ms, ETA 0:11
# Step 360/398: Loss (avg) 0.49353123695972434, Step Time 242 ms, ETA 0:9
# Step 370/398: Loss (avg) 0.47055834738189345, Step Time 237 ms, ETA 0:6
# Step 380/398: Loss (avg) 0.4485044660586196, Step Time 236 ms, ETA 0:4
# Step 390/398: Loss (avg) 0.6472795837843188, Step Time 238 ms, ETA 0:1
# Metrics for test set:
#    accuracy        f1  precision    recall  specificity    auroc      aupr  \
# 0  0.791064  0.809086   0.770537  0.851695     0.725426  0.78856  0.849662
#
#              confusion_matrix
# 0  [[1107, 419], [245, 1407]]
# Step 10/445: Loss (avg) 0.4514323995972705, Step Time 723 ms, ETA 5:14
# Step 20/445: Loss (avg) 0.6020007344764939, Step Time 725 ms, ETA 5:8
# Step 30/445: Loss (avg) 0.6478244368730198, Step Time 732 ms, ETA 5:3
# Step 40/445: Loss (avg) 0.6583627116201827, Step Time 728 ms, ETA 4:54
# Step 50/445: Loss (avg) 0.6436132564744033, Step Time 722 ms, ETA 4:45
# Step 60/445: Loss (avg) 0.6194416469449493, Step Time 729 ms, ETA 4:40
# Step 70/445: Loss (avg) 0.5897960505131328, Step Time 730 ms, ETA 4:33
# Step 80/445: Loss (avg) 0.5558354033274642, Step Time 732 ms, ETA 4:27
# Step 90/445: Loss (avg) 0.5359053354219535, Step Time 729 ms, ETA 4:18
# Step 100/445: Loss (avg) 0.5030574027078747, Step Time 724 ms, ETA 4:9
# Step 110/445: Loss (avg) 0.4798356395347484, Step Time 731 ms, ETA 4:4
# Step 120/445: Loss (avg) 0.4620443614482018, Step Time 733 ms, ETA 3:58
# Step 130/445: Loss (avg) 0.41469119938518145, Step Time 734 ms, ETA 3:51
# Step 140/445: Loss (avg) 0.41820877403546836, Step Time 730 ms, ETA 3:42
# Step 150/445: Loss (avg) 0.4340632137389888, Step Time 734 ms, ETA 3:36
# Step 160/445: Loss (avg) 0.41048307977536125, Step Time 725 ms, ETA 3:26
# Step 170/445: Loss (avg) 0.3744216213435659, Step Time 732 ms, ETA 3:21
# Step 180/445: Loss (avg) 0.4108261093879642, Step Time 734 ms, ETA 3:14
# Step 190/445: Loss (avg) 0.3736833816513233, Step Time 733 ms, ETA 3:6
# Step 200/445: Loss (avg) 0.3611611230682538, Step Time 735 ms, ETA 3:0
# Step 210/445: Loss (avg) 0.330574535230467, Step Time 725 ms, ETA 2:50
# Step 220/445: Loss (avg) 0.30632931298873256, Step Time 738 ms, ETA 2:46
# Step 230/445: Loss (avg) 0.2863354685878686, Step Time 735 ms, ETA 2:38
# Step 240/445: Loss (avg) 0.2751502204731298, Step Time 733 ms, ETA 2:30
# Step 250/445: Loss (avg) 0.2655810192659587, Step Time 735 ms, ETA 2:23
# Step 260/445: Loss (avg) 0.2823980837474967, Step Time 732 ms, ETA 2:15
# Step 270/445: Loss (avg) 0.3074260520561475, Step Time 733 ms, ETA 2:8
# Step 280/445: Loss (avg) 0.2755966705214208, Step Time 735 ms, ETA 2:1
# Step 290/445: Loss (avg) 0.2843699308461799, Step Time 726 ms, ETA 1:52
# Step 300/445: Loss (avg) 0.3034629401198914, Step Time 736 ms, ETA 1:46
# Step 310/445: Loss (avg) 0.2973901328605198, Step Time 735 ms, ETA 1:39
# Step 320/445: Loss (avg) 0.29530780620188507, Step Time 735 ms, ETA 1:31
# Step 330/445: Loss (avg) 0.28853304819165204, Step Time 735 ms, ETA 1:24
# Step 340/445: Loss (avg) 0.25316255246142655, Step Time 734 ms, ETA 1:17
# Step 350/445: Loss (avg) 0.3042765533106014, Step Time 732 ms, ETA 1:9
# Step 360/445: Loss (avg) 0.24666922923818166, Step Time 736 ms, ETA 1:2
# Step 370/445: Loss (avg) 0.26468836161635084, Step Time 732 ms, ETA 0:54
# Step 380/445: Loss (avg) 0.32405554815126425, Step Time 734 ms, ETA 0:47
# Step 390/445: Loss (avg) 0.29114843570585747, Step Time 732 ms, ETA 0:40
# Step 400/445: Loss (avg) 0.28918597808752916, Step Time 733 ms, ETA 0:32
# Step 410/445: Loss (avg) 0.2633921785046194, Step Time 734 ms, ETA 0:25
# Step 420/445: Loss (avg) 0.26001501033019403, Step Time 735 ms, ETA 0:18
# Step 430/445: Loss (avg) 0.3219829690292041, Step Time 735 ms, ETA 0:11
# Step 440/445: Loss (avg) 0.30917546344680635, Step Time 735 ms, ETA 0:3
# Step 10/398: Loss (avg) 0.38696414193474127, Step Time 236 ms, ETA 1:31
# Step 20/398: Loss (avg) 0.5123403711529079, Step Time 236 ms, ETA 1:29
# Step 30/398: Loss (avg) 0.4834217494170553, Step Time 237 ms, ETA 1:27
# Step 40/398: Loss (avg) 0.4543465403041876, Step Time 237 ms, ETA 1:24
# Step 50/398: Loss (avg) 0.448746335559713, Step Time 237 ms, ETA 1:22
# Step 60/398: Loss (avg) 0.5451396033466784, Step Time 236 ms, ETA 1:19
# Step 70/398: Loss (avg) 0.5347091905434592, Step Time 237 ms, ETA 1:17
# Step 80/398: Loss (avg) 0.5576221304068687, Step Time 237 ms, ETA 1:15
# Step 90/398: Loss (avg) 0.5813174499614225, Step Time 237 ms, ETA 1:12
# Step 100/398: Loss (avg) 0.5453915706217217, Step Time 237 ms, ETA 1:10
# Step 110/398: Loss (avg) 0.6167709311528996, Step Time 237 ms, ETA 1:8
# Step 120/398: Loss (avg) 0.5530367317443734, Step Time 236 ms, ETA 1:5
# Step 130/398: Loss (avg) 0.6475048376248475, Step Time 236 ms, ETA 1:3
# Step 140/398: Loss (avg) 0.6245485961357584, Step Time 237 ms, ETA 1:1
# Step 150/398: Loss (avg) 0.5575655612131009, Step Time 236 ms, ETA 0:58
# Step 160/398: Loss (avg) 0.5819633136494664, Step Time 236 ms, ETA 0:56
# Step 170/398: Loss (avg) 0.5775530417180792, Step Time 237 ms, ETA 0:54
# Step 180/398: Loss (avg) 0.6151577566346913, Step Time 237 ms, ETA 0:51
# Step 190/398: Loss (avg) 0.6790743465743019, Step Time 238 ms, ETA 0:49
# Step 200/398: Loss (avg) 0.543931030259229, Step Time 237 ms, ETA 0:46
# Step 210/398: Loss (avg) 0.47778957705259806, Step Time 236 ms, ETA 0:44
# Step 220/398: Loss (avg) 0.4831195332900808, Step Time 236 ms, ETA 0:42
# Step 230/398: Loss (avg) 0.3891669501303379, Step Time 237 ms, ETA 0:39
# Step 240/398: Loss (avg) 0.5481634064483046, Step Time 237 ms, ETA 0:37
# Step 250/398: Loss (avg) 0.49546890883010014, Step Time 238 ms, ETA 0:35
# Step 260/398: Loss (avg) 0.4462710432068572, Step Time 237 ms, ETA 0:32
# Step 270/398: Loss (avg) 0.460182616347894, Step Time 236 ms, ETA 0:30
# Step 280/398: Loss (avg) 0.4782854029121835, Step Time 236 ms, ETA 0:27
# Step 290/398: Loss (avg) 0.5516810096655419, Step Time 235 ms, ETA 0:25
# Step 300/398: Loss (avg) 0.45379363324008937, Step Time 236 ms, ETA 0:23
# Step 310/398: Loss (avg) 0.5072466737676437, Step Time 238 ms, ETA 0:20
# Step 320/398: Loss (avg) 0.6509218240185204, Step Time 237 ms, ETA 0:18
# Step 330/398: Loss (avg) 0.6225647236636964, Step Time 236 ms, ETA 0:16
# Step 340/398: Loss (avg) 0.5405371748241536, Step Time 236 ms, ETA 0:13
# Step 350/398: Loss (avg) 0.5980057067058862, Step Time 237 ms, ETA 0:11
# Step 360/398: Loss (avg) 0.476877507857727, Step Time 238 ms, ETA 0:9
# Step 370/398: Loss (avg) 0.4815166395782209, Step Time 235 ms, ETA 0:6
# Step 380/398: Loss (avg) 0.5357846853742965, Step Time 236 ms, ETA 0:4
# Step 390/398: Loss (avg) 0.6075320801734154, Step Time 237 ms, ETA 0:1
# Metrics for test set:
#    accuracy        f1  precision    recall  specificity    auroc      aupr  \
# 0  0.779736  0.804687   0.746377  0.872881     0.678899  0.77589  0.842669
#
#              confusion_matrix
# 0  [[1036, 490], [210, 1442]]

# %%
import pandas as pd

pred_metrics = {}

all_preds = pd.read_csv("./biochem_results/test_metrics_with_biochem_1ep.csv").mean()
pred_metrics["all_preds"] = all_preds  

samples = []
for i in range(5):
    test_metrics_no_pred = pd.read_csv(f'./biochem_results/1test_metrics_no_biochem({i}).csv')
    samples.append(test_metrics_no_pred)
pred_metrics["no_pred"] = pd.concat(samples).mean()

for biochem_pred in biochem_cols:
    samples = []
    for i in range(5):
        test_metrics_pred = pd.read_csv(f'./biochem_results/1test_metrics_only_pred_{biochem_pred}({i}).csv')
        samples.append(test_metrics_pred)
    pred_metrics[biochem_pred] = pd.concat(samples).mean()

metrics_df = pd.DataFrame(pred_metrics, index=None).transpose()

print(metrics_df)
# Out:
#                         Unnamed: 0  accuracy        f1  precision    recall  \
# all_preds                      0.0  0.796728  0.812427   0.780692  0.846852
# no_pred                        0.0  0.784707  0.804693   0.761658  0.853027
# molecular_mass                 0.0  0.787036  0.807925   0.760961  0.861380
# hydrophobic_freq               0.0  0.789553  0.809695   0.764118  0.861138
# hydrophilic_freq               0.0  0.784078  0.805214   0.758870  0.857990
# basic_freq                     0.0  0.782127  0.803792   0.755861  0.858354
# acid_freq                      0.0  0.778666  0.799984   0.754744  0.851211
# charge                         0.0  0.784581  0.804731   0.761121  0.853753
# aliphatic_index                0.0  0.761737  0.788852   0.733216  0.854479
# average_hydrophobicity         0.0  0.770925  0.796654   0.742473  0.860533
# isoelectric_point              0.0  0.781435  0.802221   0.757962  0.852421
#
#                         specificity     auroc      aupr
# all_preds                  0.742464  0.794658  0.853577
# no_pred                    0.710747  0.781887  0.845542
# molecular_mass             0.706553  0.783967  0.847200
# hydrophobic_freq           0.712058  0.786598  0.848720
# hydrophilic_freq           0.704063  0.781027  0.845340
# basic_freq                 0.699607  0.778980  0.843923
# acid_freq                  0.700131  0.775671  0.841649
# charge                     0.709699  0.781726  0.845448
# aliphatic_index            0.661337  0.757908  0.831670
# average_hydrophobicity     0.673919  0.767226  0.837752
# isoelectric_point          0.704587  0.778504  0.843549

# %%
import numpy as np
import matplotlib.pyplot as plt 

index = np.arange(len(metrics_df["accuracy"]))
tags = ["all_preds", "no_pred"] + biochem_cols

fig, axs = plt.subplots(4,2, figsize=(32, 40))

w = 0.8
C = 8

axs[0][0].barh(index, metrics_df["accuracy"], color='b')
axs[0][0].set_title("Accuracy")
axs[0][0].set_yticks(index)
axs[0][0].set_yticklabels(tags) # 0.7,0.775
mean = metrics_df["accuracy"].mean()
std = metrics_df["accuracy"].std()
axs[0][0].set_xlim(mean-C*std,mean+C*std)
axs[0][0].axvline(x = metrics_df["accuracy"]["no_pred"], color = 'k')
axs[0][0].invert_yaxis()  # labels read top-to-bottom

axs[0][1].barh(index, metrics_df["precision"], color='g')
axs[0][1].set_title("Precision")
axs[0][1].set_yticks(index)
axs[0][1].set_yticklabels(tags)
mean = metrics_df["precision"].mean()
std = metrics_df["precision"].std()
axs[0][1].set_xlim(mean-C*std,mean+C*std)
axs[0][1].axvline(x = metrics_df["precision"]["no_pred"], color = 'k')
axs[0][1].invert_yaxis()  # labels read top-to-bottom

axs[1][0].barh(index, metrics_df["f1"], color='r')
axs[1][0].set_title("F1")
axs[1][0].set_yticks(index)
axs[1][0].set_yticklabels(tags)
mean = metrics_df["f1"].mean()
std = metrics_df["f1"].std()
axs[1][0].set_xlim(mean-C*std,mean+C*std)
axs[1][0].axvline(x = metrics_df["f1"]["no_pred"], color = 'k')
axs[1][0].invert_yaxis()  # labels read top-to-bottom

axs[1][1].barh(index, metrics_df["recall"], color='c')
axs[1][1].set_title("Recall")
axs[1][1].set_yticks(index)
axs[1][1].set_yticklabels(tags)
mean = metrics_df["recall"].mean()
std = metrics_df["recall"].std()
axs[1][1].set_xlim(mean-C*std,mean+C*std)
axs[1][1].axvline(x = metrics_df["recall"]["no_pred"], color = 'k')
axs[1][1].invert_yaxis()  # labels read top-to-bottom

axs[2][0].barh(index, metrics_df["specificity"], color='m')
axs[2][0].set_title("Specificity")
axs[2][0].set_yticks(index)
axs[2][0].set_yticklabels(tags)
mean = metrics_df["specificity"].mean()
std = metrics_df["specificity"].std()
axs[2][0].set_xlim(mean-C*std,mean+C*std)
axs[2][0].axvline(x = metrics_df["specificity"]["no_pred"], color = 'k')
axs[2][0].invert_yaxis()  # labels read top-to-bottom

axs[2][1].barh(index, metrics_df["auroc"], color='y')
axs[2][1].set_title("Area under ROC")
axs[2][1].set_yticks(index)
axs[2][1].set_yticklabels(tags)
mean = metrics_df["auroc"].mean()
std = metrics_df["auroc"].std()
axs[2][1].set_xlim(mean-C*std,mean+C*std)
axs[2][1].axvline(x = metrics_df["auroc"]["no_pred"], color = 'k')
axs[2][1].invert_yaxis()  # labels read top-to-bottom

axs[3][0].barh(index, metrics_df["aupr"], color='k')
axs[3][0].set_title("Area under PRC")
axs[3][0].set_yticks(index)
axs[3][0].set_yticklabels(tags)
mean = metrics_df["aupr"].mean()
std = metrics_df["aupr"].std()
axs[3][0].set_xlim(mean-C*std,mean+C*std)
axs[3][0].axvline(x = metrics_df["aupr"]["no_pred"], color = 'k')
axs[3][0].invert_yaxis()  # labels read top-to-bottom


##############



plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt 

index = np.arange(len(metrics_df["accuracy"]))
tags = ["all_preds", "no_pred"] + biochem_cols

fig, axs = plt.subplots(1,1, figsize=(18, 10))

w = 0.8
C = 8

metrics_df = metrics_df.sort_values(by=['f1'], ascending=False)

axs.barh(index, metrics_df["f1"], color='r')
axs.set_title("F1", fontsize=32)
axs.set_yticks(index)
axs.set_yticklabels(metrics_df.index, fontsize=18)
mean = metrics_df["f1"].mean()
std = metrics_df["f1"].std()
axs.set_xlim(mean-C*std,mean+C*std)
axs.axvline(x = metrics_df["f1"]["no_pred"], color = 'k')
axs.invert_yaxis()  # labels read top-to-bottom
axs.tick_params(axis='both', which='major', labelsize=18)
axs.tick_params(axis='both', which='minor', labelsize=18)
##############



plt.show()

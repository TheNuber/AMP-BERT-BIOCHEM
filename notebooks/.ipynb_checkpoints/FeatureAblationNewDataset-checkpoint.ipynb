# %% [markdown]
# # Evaluación de importancia de cada predictor bioquímico global

# %% [markdown]
# ## Vamos a ver cómo afecta cada predictor bioquímico por separado al rendimiento del modelo AMP-BERT-BIOCHEM

# %%
import pandas as pd
import torch

SEED = 0
FRAC_TRAIN = 0.5

torch.manual_seed(SEED)

df = pd.read_csv('./datasets/database_all_propiedades.csv', index_col = 0)
print(df.columns)
# Out:
# Index(['PubMed_ID', 'Sequence', 'Activity', 'code', 'AMP', 'len_seq',
#        'molecular_mass', 'aa_count', 'aa_freq', 'aa_missing', 'aa_more_freq',
#        'hydrophobic_freq', 'hydrophilic_freq', 'basic_freq', 'acid_freq',
#        'charge', 'aliphatic_index', 'average_hydrophobicity',
#        'isoelectric_point'],
#       dtype='object')

# %%
df = df.rename(columns = {
    'Sequence': 'aa_seq',
})

df_pos = df[df["AMP"] == True]
df_neg = df[df["AMP"] == False]

train_df_pos = df_pos.sample(frac=FRAC_TRAIN, random_state=SEED)
train_df_neg = df_neg.sample(frac=FRAC_TRAIN, random_state=SEED)
test_df_pos = df_pos.drop(train_df_pos.index)
test_df_neg = df_neg.drop(train_df_neg.index)

train_df = pd.concat([train_df_pos, train_df_neg])
test_df = pd.concat([test_df_pos, test_df_neg])

print(f"Train dataframe: {len(train_df_pos)} positives, {len(test_df_neg)} negatives ({len(train_df_pos)/len(train_df)}%)")
print(f"Test dataframe: {len(test_df_pos)} positives, {len(test_df_neg)} negatives ({len(test_df_pos)/len(test_df)}%)")
# Out:
# Train dataframe: 4443 positives, 2816 negatives (0.6120677779308444%)
# Test dataframe: 4443 positives, 2816 negatives (0.6120677779308444%)

# %%
from pipeline_tools import AMP_BioChemDataLoader, train_model, eval_model, compute_metrics
from torch.optim import AdamW
from transformers import BertForSequenceClassification, get_linear_schedule_with_warmup
from MultiGPUModels import MultiGPUBertForPeptideClassification
import torch
from torch.nn import CrossEntropyLoss
from copy import deepcopy

BATCH_SIZE = 8
LEARNING_RATE = 5e-6
WEIGHT_DECAY = 0.01
EPOCHS = 1
            
biochem_cols = [
    "molecular_mass",
    "hydrophobic_freq",
    "hydrophilic_freq",
    "basic_freq",
    "acid_freq",
    "charge",
    "aliphatic_index",
    "average_hydrophobicity",
    "isoelectric_point"
]


bert_model = BertForSequenceClassification.from_pretrained('Rostlab/prot_bert_bfd')
# Out:
# Some weights of the model checkpoint at Rostlab/prot_bert_bfd were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at Rostlab/prot_bert_bfd and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def train_with_cols(biochem_cols):
    train_dataloader = AMP_BioChemDataLoader(train_df, biochem_cols, batch_size = BATCH_SIZE)            
    test_dataloader = AMP_BioChemDataLoader(test_df, biochem_cols, batch_size = BATCH_SIZE)            

    multi_gpu_bert_pred = MultiGPUBertForPeptideClassification(bert_model, biochem_cols)
            
    # Entrenar el modelo con esta configuracion
    optimizer = AdamW(
        multi_gpu_bert_pred.parameters(), 
        lr = LEARNING_RATE, 
        weight_decay = WEIGHT_DECAY)
            
    total_steps = len(train_dataloader) * EPOCHS
            
    scheduler = get_linear_schedule_with_warmup(optimizer, 
        num_warmup_steps = 0, 
        num_training_steps = total_steps)

    for i in range(EPOCHS):
        train_model(multi_gpu_bert_pred, train_dataloader, CrossEntropyLoss(), optimizer, scheduler, True)
            
    # Obtener las métricas de validacion
    test_labels, test_preds = eval_model(multi_gpu_bert_pred, test_dataloader, CrossEntropyLoss(), True)
    test_metrics = compute_metrics(test_labels, test_preds)

    print(f"Metrics for test set: ")
    print(test_metrics)
    
    del multi_gpu_bert_pred
    return test_metrics

# %%
for i in range(5):
    test_metrics_all_biochem = train_with_cols(biochem_cols)
    test_metrics_all_biochem.to_csv(f'./newdata_results/test_metrics_all_biochem({i}).csv')
    
for i in range(5):
    test_metrics_no_biochem = train_with_cols([])
    test_metrics_no_biochem.to_csv(f'./newdata_results/test_metrics_no_biochem({i}).csv')

    for biochem_pred in biochem_cols:
        test_metrics_pred = train_with_cols([biochem_pred])
        test_metrics_pred.to_csv(f'./newdata_results/test_metrics_only_pred_{biochem_pred}({i}).csv')
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# Step 10/908: Loss (avg) 0.4800467231969535, Step Time 708 ms, ETA 10:35
# Step 20/908: Loss (avg) 0.6320446951765646, Step Time 712 ms, ETA 10:32
# Step 30/908: Loss (avg) 0.6960920497034587, Step Time 716 ms, ETA 10:28
# Step 40/908: Loss (avg) 0.6981060478982293, Step Time 717 ms, ETA 10:22
# Step 50/908: Loss (avg) 0.6964454551276084, Step Time 719 ms, ETA 10:16
# Step 60/908: Loss (avg) 0.6880628435269899, Step Time 718 ms, ETA 10:8
# Step 70/908: Loss (avg) 0.6612105157653172, Step Time 722 ms, ETA 10:5
# Step 80/908: Loss (avg) 0.65030337254263, Step Time 722 ms, ETA 9:57
# Step 90/908: Loss (avg) 0.6407692354252933, Step Time 723 ms, ETA 9:51
# Step 100/908: Loss (avg) 0.6782560402596279, Step Time 723 ms, ETA 9:44
# Step 110/908: Loss (avg) 0.7036282770880722, Step Time 723 ms, ETA 9:36
# Step 120/908: Loss (avg) 0.7066808565468736, Step Time 724 ms, ETA 9:30
# Step 130/908: Loss (avg) 0.6904439234813065, Step Time 724 ms, ETA 9:23
# Step 140/908: Loss (avg) 0.6712617974974237, Step Time 724 ms, ETA 9:16
# Step 150/908: Loss (avg) 0.6600603253015354, Step Time 725 ms, ETA 9:9
# Step 160/908: Loss (avg) 0.6417799164236374, Step Time 718 ms, ETA 8:57
# Step 170/908: Loss (avg) 0.6855681761660758, Step Time 722 ms, ETA 8:52
# Step 180/908: Loss (avg) 0.6540510903441907, Step Time 730 ms, ETA 8:51
# Step 190/908: Loss (avg) 0.6542080719650568, Step Time 726 ms, ETA 8:41
# Step 200/908: Loss (avg) 0.6278045375924812, Step Time 727 ms, ETA 8:34
# Step 210/908: Loss (avg) 0.6069696637025374, Step Time 728 ms, ETA 8:28
# Step 220/908: Loss (avg) 0.622512260962929, Step Time 728 ms, ETA 8:20
# Step 230/908: Loss (avg) 0.613072657300698, Step Time 730 ms, ETA 8:14
# Step 240/908: Loss (avg) 0.6045280162213396, Step Time 729 ms, ETA 8:6
# Step 250/908: Loss (avg) 0.6223006506598647, Step Time 728 ms, ETA 7:59
# Step 260/908: Loss (avg) 0.5866752885388141, Step Time 730 ms, ETA 7:53
# Step 270/908: Loss (avg) 0.5848827268143739, Step Time 728 ms, ETA 7:44
# Step 280/908: Loss (avg) 0.5425226166772884, Step Time 731 ms, ETA 7:39
# Step 290/908: Loss (avg) 0.6902270087686799, Step Time 728 ms, ETA 7:29
# Step 300/908: Loss (avg) 0.6334355095943196, Step Time 731 ms, ETA 7:24
# Step 310/908: Loss (avg) 0.5609506080101762, Step Time 730 ms, ETA 7:16
# Step 320/908: Loss (avg) 0.621333046609377, Step Time 728 ms, ETA 7:8
# Step 330/908: Loss (avg) 0.5598550056541011, Step Time 730 ms, ETA 7:1
# Step 340/908: Loss (avg) 0.6397955720183712, Step Time 732 ms, ETA 6:55
# Step 350/908: Loss (avg) 0.625294441941252, Step Time 731 ms, ETA 6:47
# Step 360/908: Loss (avg) 0.6160349496365504, Step Time 732 ms, ETA 6:41
# Step 370/908: Loss (avg) 0.5915881092937443, Step Time 731 ms, ETA 6:33
# Step 380/908: Loss (avg) 0.642220828412668, Step Time 732 ms, ETA 6:26
# Step 390/908: Loss (avg) 0.5926049350119873, Step Time 732 ms, ETA 6:19
# Step 400/908: Loss (avg) 0.6010339586844103, Step Time 732 ms, ETA 6:11
# Step 410/908: Loss (avg) 0.5665662691618374, Step Time 731 ms, ETA 6:4
# Step 420/908: Loss (avg) 0.5966877207183414, Step Time 732 ms, ETA 5:57
# Step 430/908: Loss (avg) 0.5839410457899028, Step Time 730 ms, ETA 5:48
# Step 440/908: Loss (avg) 0.5721274966183634, Step Time 731 ms, ETA 5:42
# Step 450/908: Loss (avg) 0.544800671411203, Step Time 732 ms, ETA 5:35
# Step 460/908: Loss (avg) 0.5689172971207175, Step Time 731 ms, ETA 5:27
# Step 470/908: Loss (avg) 0.6223971265900513, Step Time 732 ms, ETA 5:20
# Step 480/908: Loss (avg) 0.6389166130804094, Step Time 734 ms, ETA 5:14
# Step 490/908: Loss (avg) 0.6231986230730827, Step Time 731 ms, ETA 5:5
# Step 500/908: Loss (avg) 0.642590725806899, Step Time 732 ms, ETA 4:58
# Step 510/908: Loss (avg) 0.6146266542320336, Step Time 732 ms, ETA 4:51
# Step 520/908: Loss (avg) 0.5906940620387182, Step Time 733 ms, ETA 4:44
# Step 530/908: Loss (avg) 0.5964270035719177, Step Time 731 ms, ETA 4:36
# Step 540/908: Loss (avg) 0.5854221447124823, Step Time 735 ms, ETA 4:30
# Step 550/908: Loss (avg) 0.5448613233264397, Step Time 731 ms, ETA 4:21
# Step 560/908: Loss (avg) 0.5601983817433822, Step Time 733 ms, ETA 4:15
# Step 570/908: Loss (avg) 0.5519539367236427, Step Time 729 ms, ETA 4:6
# Step 580/908: Loss (avg) 0.5866680373712567, Step Time 731 ms, ETA 3:59
# Step 590/908: Loss (avg) 0.6495229346170039, Step Time 730 ms, ETA 3:52
# Step 600/908: Loss (avg) 0.6229411206886607, Step Time 722 ms, ETA 3:42
# Step 610/908: Loss (avg) 0.5887583920076052, Step Time 731 ms, ETA 3:37
# Step 620/908: Loss (avg) 0.5874213267557237, Step Time 732 ms, ETA 3:30
# Step 630/908: Loss (avg) 0.5879445933371606, Step Time 733 ms, ETA 3:23
# Step 640/908: Loss (avg) 0.6484899310915104, Step Time 733 ms, ETA 3:16
# Step 650/908: Loss (avg) 0.5870444433692957, Step Time 733 ms, ETA 3:9
# Step 660/908: Loss (avg) 0.564375977186602, Step Time 730 ms, ETA 3:1
# Step 670/908: Loss (avg) 0.572901284934553, Step Time 732 ms, ETA 2:54
# Step 680/908: Loss (avg) 0.6191278100377834, Step Time 732 ms, ETA 2:46
# Step 690/908: Loss (avg) 0.576519289912492, Step Time 733 ms, ETA 2:39
# Step 700/908: Loss (avg) 0.6248661212045185, Step Time 732 ms, ETA 2:32
# Step 710/908: Loss (avg) 0.6234791192470891, Step Time 732 ms, ETA 2:24
# Step 720/908: Loss (avg) 0.5747943835277763, Step Time 731 ms, ETA 2:17
# Step 730/908: Loss (avg) 0.5699796237941197, Step Time 731 ms, ETA 2:10
# Step 740/908: Loss (avg) 0.5302680395165716, Step Time 734 ms, ETA 2:3
# Step 750/908: Loss (avg) 0.5619252772713706, Step Time 733 ms, ETA 1:55
# Step 760/908: Loss (avg) 0.5802054847901807, Step Time 732 ms, ETA 1:48
# Step 770/908: Loss (avg) 0.5528218952187611, Step Time 731 ms, ETA 1:40
# Step 780/908: Loss (avg) 0.6296810404060735, Step Time 733 ms, ETA 1:33
# Step 790/908: Loss (avg) 0.5487295980966873, Step Time 734 ms, ETA 1:26
# Step 800/908: Loss (avg) 0.5813534867331362, Step Time 732 ms, ETA 1:19
# Step 810/908: Loss (avg) 0.5847776880517477, Step Time 733 ms, ETA 1:11
# Step 820/908: Loss (avg) 0.622132504943949, Step Time 730 ms, ETA 1:4
# Step 830/908: Loss (avg) 0.5983862937551465, Step Time 733 ms, ETA 0:57
# Step 840/908: Loss (avg) 0.5927344560903048, Step Time 731 ms, ETA 0:49
# Step 850/908: Loss (avg) 0.6000420676157593, Step Time 732 ms, ETA 0:42
# Step 860/908: Loss (avg) 0.5564789995003137, Step Time 736 ms, ETA 0:35
# Step 870/908: Loss (avg) 0.587921392358044, Step Time 733 ms, ETA 0:27
# Step 880/908: Loss (avg) 0.6030126902001232, Step Time 733 ms, ETA 0:20
# Step 890/908: Loss (avg) 0.5636490828055295, Step Time 732 ms, ETA 0:13
# Step 900/908: Loss (avg) 0.5785668644985921, Step Time 733 ms, ETA 0:5
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# Step 10/908: Loss (avg) 0.41311610933771176, Step Time 238 ms, ETA 3:33
# Step 20/908: Loss (avg) 0.4925853726233984, Step Time 237 ms, ETA 3:30
# Step 30/908: Loss (avg) 0.5334291610932731, Step Time 237 ms, ETA 3:28
# Step 40/908: Loss (avg) 0.48235458715098345, Step Time 236 ms, ETA 3:24
# Step 50/908: Loss (avg) 0.5723916515817699, Step Time 235 ms, ETA 3:21
# Step 60/908: Loss (avg) 0.6364609174911092, Step Time 236 ms, ETA 3:20
# Step 70/908: Loss (avg) 0.5902989151085756, Step Time 237 ms, ETA 3:18
# Step 80/908: Loss (avg) 0.5014348505197097, Step Time 236 ms, ETA 3:15
# Step 90/908: Loss (avg) 0.556573935709985, Step Time 236 ms, ETA 3:13
# Step 100/908: Loss (avg) 0.5667859158457584, Step Time 236 ms, ETA 3:10
# Step 110/908: Loss (avg) 0.5733412352631156, Step Time 236 ms, ETA 3:8
# Step 120/908: Loss (avg) 0.5559124824291495, Step Time 236 ms, ETA 3:5
# Step 130/908: Loss (avg) 0.5746613278663402, Step Time 235 ms, ETA 3:2
# Step 140/908: Loss (avg) 0.6301714616085297, Step Time 235 ms, ETA 3:0
# Step 150/908: Loss (avg) 0.6216857412706361, Step Time 236 ms, ETA 2:58
# Step 160/908: Loss (avg) 0.6084055810222683, Step Time 237 ms, ETA 2:57
# Step 170/908: Loss (avg) 0.6247118008650743, Step Time 238 ms, ETA 2:55
# Step 180/908: Loss (avg) 0.5471050586339129, Step Time 236 ms, ETA 2:51
# Step 190/908: Loss (avg) 0.6052690727268264, Step Time 236 ms, ETA 2:49
# Step 200/908: Loss (avg) 0.5709613315562261, Step Time 236 ms, ETA 2:47
# Step 210/908: Loss (avg) 0.6396463600717531, Step Time 235 ms, ETA 2:44
# Step 220/908: Loss (avg) 0.5771183467247334, Step Time 236 ms, ETA 2:42
# Step 230/908: Loss (avg) 0.6162202574991045, Step Time 237 ms, ETA 2:40
# Step 240/908: Loss (avg) 0.563035122556625, Step Time 235 ms, ETA 2:36
# Step 250/908: Loss (avg) 0.557090431968615, Step Time 235 ms, ETA 2:34
# Step 260/908: Loss (avg) 0.5210770131476987, Step Time 237 ms, ETA 2:33
# Step 270/908: Loss (avg) 0.5728849822403671, Step Time 236 ms, ETA 2:30
# Step 280/908: Loss (avg) 0.5422620466346643, Step Time 236 ms, ETA 2:28
# Step 290/908: Loss (avg) 0.6045077928307594, Step Time 236 ms, ETA 2:25
# Step 300/908: Loss (avg) 0.6075850856187743, Step Time 236 ms, ETA 2:23
# Step 310/908: Loss (avg) 0.5396947358025095, Step Time 236 ms, ETA 2:21
# Step 320/908: Loss (avg) 0.5429222396161232, Step Time 236 ms, ETA 2:18
# Step 330/908: Loss (avg) 0.5357100080562923, Step Time 237 ms, ETA 2:16
# Step 340/908: Loss (avg) 0.5315088496969069, Step Time 239 ms, ETA 2:15
# Step 350/908: Loss (avg) 0.5749255110668805, Step Time 236 ms, ETA 2:11
# Step 360/908: Loss (avg) 0.5224091260300229, Step Time 236 ms, ETA 2:9
# Step 370/908: Loss (avg) 0.6024882523254053, Step Time 237 ms, ETA 2:7
# Step 380/908: Loss (avg) 0.6435971771295681, Step Time 237 ms, ETA 2:5
# Step 390/908: Loss (avg) 0.5533464866948123, Step Time 235 ms, ETA 2:1
# Step 400/908: Loss (avg) 0.5509094501222079, Step Time 237 ms, ETA 2:0
# Step 410/908: Loss (avg) 0.5713395117085028, Step Time 237 ms, ETA 1:58
# Step 420/908: Loss (avg) 0.5141371357683362, Step Time 237 ms, ETA 1:55
# Step 430/908: Loss (avg) 0.5241342208691522, Step Time 237 ms, ETA 1:53
# Step 440/908: Loss (avg) 0.5357791963430619, Step Time 237 ms, ETA 1:50
# Step 450/908: Loss (avg) 0.5549196038926485, Step Time 237 ms, ETA 1:48
# Step 460/908: Loss (avg) 0.5852002391286028, Step Time 236 ms, ETA 1:45
# Step 470/908: Loss (avg) 0.5870250054502232, Step Time 235 ms, ETA 1:42
# Step 480/908: Loss (avg) 0.6456650587474613, Step Time 237 ms, ETA 1:41
# Step 490/908: Loss (avg) 0.5941243757427834, Step Time 237 ms, ETA 1:39
# Step 500/908: Loss (avg) 0.5230328145009139, Step Time 236 ms, ETA 1:36
# Step 510/908: Loss (avg) 0.543238980968798, Step Time 237 ms, ETA 1:34
# Step 520/908: Loss (avg) 0.6263107534555332, Step Time 235 ms, ETA 1:31
# Step 530/908: Loss (avg) 0.5628887559141731, Step Time 236 ms, ETA 1:29
# Step 540/908: Loss (avg) 0.6038916003858613, Step Time 236 ms, ETA 1:26
# Step 550/908: Loss (avg) 0.6156833183719579, Step Time 237 ms, ETA 1:24
# Step 560/908: Loss (avg) 0.5483181746327336, Step Time 236 ms, ETA 1:22
# Step 570/908: Loss (avg) 0.6069244237771814, Step Time 237 ms, ETA 1:20
# Step 580/908: Loss (avg) 0.5897980984986824, Step Time 236 ms, ETA 1:17
# Step 590/908: Loss (avg) 0.5672995910712514, Step Time 236 ms, ETA 1:15
# Step 600/908: Loss (avg) 0.5857068450196274, Step Time 235 ms, ETA 1:12
# Step 610/908: Loss (avg) 0.5596133676512884, Step Time 236 ms, ETA 1:10
# Step 620/908: Loss (avg) 0.5571087815769173, Step Time 242 ms, ETA 1:9
# Step 630/908: Loss (avg) 0.5298008881267777, Step Time 237 ms, ETA 1:5
# Step 640/908: Loss (avg) 0.5424593339267997, Step Time 236 ms, ETA 1:3
# Step 650/908: Loss (avg) 0.5403581475330607, Step Time 236 ms, ETA 1:0
# Step 660/908: Loss (avg) 0.5894524680768308, Step Time 236 ms, ETA 0:58
# Step 670/908: Loss (avg) 0.5630095815147774, Step Time 236 ms, ETA 0:56
# Step 680/908: Loss (avg) 0.5422468170556262, Step Time 237 ms, ETA 0:54
# Step 690/908: Loss (avg) 0.5185179046297567, Step Time 238 ms, ETA 0:51
# Step 700/908: Loss (avg) 0.5857099434762679, Step Time 236 ms, ETA 0:49
# Step 710/908: Loss (avg) 0.562836112591562, Step Time 236 ms, ETA 0:46
# Step 720/908: Loss (avg) 0.532339438402608, Step Time 236 ms, ETA 0:44
# Step 730/908: Loss (avg) 0.5909071817629222, Step Time 237 ms, ETA 0:42
# Step 740/908: Loss (avg) 0.5402485550220493, Step Time 237 ms, ETA 0:39
# Step 750/908: Loss (avg) 0.5360018075706596, Step Time 237 ms, ETA 0:37
# Step 760/908: Loss (avg) 0.5403072189360031, Step Time 236 ms, ETA 0:34
# Step 770/908: Loss (avg) 0.5299405115315168, Step Time 236 ms, ETA 0:32
# Step 780/908: Loss (avg) 0.5826452372473214, Step Time 237 ms, ETA 0:30
# Step 790/908: Loss (avg) 0.5679286965311572, Step Time 236 ms, ETA 0:27
# Step 800/908: Loss (avg) 0.5969792294561964, Step Time 237 ms, ETA 0:25
# Step 810/908: Loss (avg) 0.6177383495058271, Step Time 236 ms, ETA 0:23
# Step 820/908: Loss (avg) 0.5533151780880816, Step Time 235 ms, ETA 0:20
# Step 830/908: Loss (avg) 0.5688882246552288, Step Time 236 ms, ETA 0:18
# Step 840/908: Loss (avg) 0.5569022608882743, Step Time 237 ms, ETA 0:16
# Step 850/908: Loss (avg) 0.6243243510069267, Step Time 236 ms, ETA 0:13
# Step 860/908: Loss (avg) 0.5953623110197798, Step Time 237 ms, ETA 0:11
# Step 870/908: Loss (avg) 0.5924288400048878, Step Time 237 ms, ETA 0:9
# Step 880/908: Loss (avg) 0.6356856671595252, Step Time 236 ms, ETA 0:6
# Step 890/908: Loss (avg) 0.5501837942802486, Step Time 236 ms, ETA 0:4
# Step 900/908: Loss (avg) 0.6065909544458936, Step Time 237 ms, ETA 0:1
# Metrics for test set:
#    accuracy        f1  precision    recall  specificity     auroc      aupr  \
# 0   0.71401  0.771868   0.754134  0.790457     0.593395  0.691926  0.836423
#
#               confusion_matrix
# 0  [[1671, 1145], [931, 3512]]
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# Step 10/908: Loss (avg) 0.43908457014506647, Step Time 723 ms, ETA 10:49
# Step 20/908: Loss (avg) 0.552901188129883, Step Time 724 ms, ETA 10:42
# Step 30/908: Loss (avg) 0.6201166354051769, Step Time 726 ms, ETA 10:37
# Step 40/908: Loss (avg) 0.6174440692068924, Step Time 727 ms, ETA 10:31
# Step 50/908: Loss (avg) 0.6032976815193248, Step Time 730 ms, ETA 10:26
# Step 60/908: Loss (avg) 0.6030318126580877, Step Time 730 ms, ETA 10:19
# Step 70/908: Loss (avg) 0.6210278491744262, Step Time 729 ms, ETA 10:10
# Step 80/908: Loss (avg) 0.5861861752231922, Step Time 730 ms, ETA 10:4
# Step 90/908: Loss (avg) 0.5637540724061764, Step Time 729 ms, ETA 9:56
# Step 100/908: Loss (avg) 0.5894298015171848, Step Time 731 ms, ETA 9:50
# Step 110/908: Loss (avg) 0.5482459295184593, Step Time 727 ms, ETA 9:40
# Step 120/908: Loss (avg) 0.5154499400436915, Step Time 732 ms, ETA 9:36
# Step 130/908: Loss (avg) 0.5294918000909382, Step Time 732 ms, ETA 9:29
# Step 140/908: Loss (avg) 0.5481794064576132, Step Time 732 ms, ETA 9:22
# Step 150/908: Loss (avg) 0.5597733168493833, Step Time 731 ms, ETA 9:14
# Step 160/908: Loss (avg) 0.5310367856228086, Step Time 731 ms, ETA 9:6
# Step 170/908: Loss (avg) 0.6032101025333945, Step Time 732 ms, ETA 9:0
# Step 180/908: Loss (avg) 0.5607737898087349, Step Time 734 ms, ETA 8:54
# Step 190/908: Loss (avg) 0.6265009120601543, Step Time 732 ms, ETA 8:45
# Step 200/908: Loss (avg) 0.5584724140107452, Step Time 735 ms, ETA 8:40
# Step 210/908: Loss (avg) 0.6280224948301482, Step Time 732 ms, ETA 8:30
# Step 220/908: Loss (avg) 0.6390658055563634, Step Time 732 ms, ETA 8:23
# Step 230/908: Loss (avg) 0.6144830353990937, Step Time 732 ms, ETA 8:16
# Step 240/908: Loss (avg) 0.5861707587610202, Step Time 735 ms, ETA 8:10
# Step 250/908: Loss (avg) 0.5376950059630439, Step Time 735 ms, ETA 8:3
# Step 260/908: Loss (avg) 0.5977058896383777, Step Time 733 ms, ETA 7:54
# Step 270/908: Loss (avg) 0.6100176447288586, Step Time 731 ms, ETA 7:46
# Step 280/908: Loss (avg) 0.5581652340532416, Step Time 734 ms, ETA 7:40
# Step 290/908: Loss (avg) 0.5929187340731923, Step Time 733 ms, ETA 7:32
# Step 300/908: Loss (avg) 0.6014121461280749, Step Time 732 ms, ETA 7:25
# Step 310/908: Loss (avg) 0.6119423134507579, Step Time 734 ms, ETA 7:18
# Step 320/908: Loss (avg) 0.5871080434358926, Step Time 734 ms, ETA 7:11
# Step 330/908: Loss (avg) 0.5976546469734261, Step Time 732 ms, ETA 7:3
# Step 340/908: Loss (avg) 0.5532041721902347, Step Time 733 ms, ETA 6:56
# Step 350/908: Loss (avg) 0.6440872415668158, Step Time 734 ms, ETA 6:49
# Step 360/908: Loss (avg) 0.6095140440650112, Step Time 729 ms, ETA 6:39
# Step 370/908: Loss (avg) 0.5530869632940683, Step Time 734 ms, ETA 6:34
# Step 380/908: Loss (avg) 0.5741588444283785, Step Time 734 ms, ETA 6:27
# Step 390/908: Loss (avg) 0.5554015777545852, Step Time 731 ms, ETA 6:18
# Step 400/908: Loss (avg) 0.5710609554901853, Step Time 733 ms, ETA 6:12
# Step 410/908: Loss (avg) 0.5362385580426666, Step Time 733 ms, ETA 6:5
# Step 420/908: Loss (avg) 0.5493602386051379, Step Time 724 ms, ETA 5:53
# Step 430/908: Loss (avg) 0.6042357227040186, Step Time 735 ms, ETA 5:51
# Step 440/908: Loss (avg) 0.5778551418921564, Step Time 732 ms, ETA 5:42
# Step 450/908: Loss (avg) 0.5794949469373408, Step Time 732 ms, ETA 5:35
# Step 460/908: Loss (avg) 0.5549578829501219, Step Time 733 ms, ETA 5:28
# Step 470/908: Loss (avg) 0.5363654046010287, Step Time 733 ms, ETA 5:21
# Step 480/908: Loss (avg) 0.5594017618779984, Step Time 735 ms, ETA 5:14
# Step 490/908: Loss (avg) 0.5150684561722495, Step Time 733 ms, ETA 5:6
# Step 500/908: Loss (avg) 0.4981810508747571, Step Time 732 ms, ETA 4:58
# Step 510/908: Loss (avg) 0.5732518561960362, Step Time 731 ms, ETA 4:50
# Step 520/908: Loss (avg) 0.5894113274104438, Step Time 733 ms, ETA 4:44
# Step 530/908: Loss (avg) 0.5701979102968014, Step Time 732 ms, ETA 4:36
# Step 540/908: Loss (avg) 0.5186388561751643, Step Time 732 ms, ETA 4:29
# Step 550/908: Loss (avg) 0.5981108949083969, Step Time 733 ms, ETA 4:22
# Step 560/908: Loss (avg) 0.6273152641265632, Step Time 734 ms, ETA 4:15
# Step 570/908: Loss (avg) 0.5776699814831627, Step Time 735 ms, ETA 4:8
# Step 580/908: Loss (avg) 0.6294726604469203, Step Time 733 ms, ETA 4:0
# Step 590/908: Loss (avg) 0.5843598917453976, Step Time 736 ms, ETA 3:54
# Step 600/908: Loss (avg) 0.5911858697903363, Step Time 735 ms, ETA 3:46
# Step 610/908: Loss (avg) 0.5567911112736508, Step Time 732 ms, ETA 3:38
# Step 620/908: Loss (avg) 0.6213182244748725, Step Time 735 ms, ETA 3:31
# Step 630/908: Loss (avg) 0.6452377852957447, Step Time 732 ms, ETA 3:23
# Step 640/908: Loss (avg) 0.5648740883689609, Step Time 734 ms, ETA 3:16
# Step 650/908: Loss (avg) 0.5378022480610386, Step Time 735 ms, ETA 3:9
# Step 660/908: Loss (avg) 0.5575785413557711, Step Time 730 ms, ETA 3:1
# Step 670/908: Loss (avg) 0.5715635318953836, Step Time 733 ms, ETA 2:54
# Step 680/908: Loss (avg) 0.5887977405110214, Step Time 734 ms, ETA 2:47
# Step 690/908: Loss (avg) 0.5480835403921107, Step Time 734 ms, ETA 2:40
# Step 700/908: Loss (avg) 0.48931088266916134, Step Time 736 ms, ETA 2:33
# Step 710/908: Loss (avg) 0.5557022981759172, Step Time 733 ms, ETA 2:25
# Step 720/908: Loss (avg) 0.5336567072225941, Step Time 733 ms, ETA 2:17
# Step 730/908: Loss (avg) 0.5033759456238399, Step Time 731 ms, ETA 2:10
# Step 740/908: Loss (avg) 0.5348631160605037, Step Time 733 ms, ETA 2:3
# Step 750/908: Loss (avg) 0.516910252150032, Step Time 732 ms, ETA 1:55
# Step 760/908: Loss (avg) 0.4418181070366361, Step Time 727 ms, ETA 1:47
# Step 770/908: Loss (avg) 0.5287110120015617, Step Time 735 ms, ETA 1:41
# Step 780/908: Loss (avg) 0.5424929608909707, Step Time 734 ms, ETA 1:33
# Step 790/908: Loss (avg) 0.5448243723994617, Step Time 732 ms, ETA 1:26
# Step 800/908: Loss (avg) 0.5380005365961159, Step Time 737 ms, ETA 1:19
# Step 810/908: Loss (avg) 0.6099212091875523, Step Time 738 ms, ETA 1:12
# Step 820/908: Loss (avg) 0.5710851188387046, Step Time 733 ms, ETA 1:4
# Step 830/908: Loss (avg) 0.5368520455193714, Step Time 732 ms, ETA 0:57
# Step 840/908: Loss (avg) 0.5635556689704045, Step Time 735 ms, ETA 0:49
# Step 850/908: Loss (avg) 0.542739768927789, Step Time 734 ms, ETA 0:42
# Step 860/908: Loss (avg) 0.5989425206349958, Step Time 733 ms, ETA 0:35
# Step 870/908: Loss (avg) 0.5836011417588165, Step Time 732 ms, ETA 0:27
# Step 880/908: Loss (avg) 0.5402014880901458, Step Time 734 ms, ETA 0:20
# Step 890/908: Loss (avg) 0.5566785132269894, Step Time 733 ms, ETA 0:13
# Step 900/908: Loss (avg) 0.5877965410233238, Step Time 731 ms, ETA 0:5
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# Step 10/908: Loss (avg) 0.358966485613917, Step Time 240 ms, ETA 3:35
# Step 20/908: Loss (avg) 0.4395500548258204, Step Time 236 ms, ETA 3:29
# Step 30/908: Loss (avg) 0.5779298305601178, Step Time 235 ms, ETA 3:26
# Step 40/908: Loss (avg) 0.6023179134574217, Step Time 236 ms, ETA 3:24
# Step 50/908: Loss (avg) 0.5457040325871039, Step Time 237 ms, ETA 3:23
# Step 60/908: Loss (avg) 0.5256506121217001, Step Time 237 ms, ETA 3:20
# Step 70/908: Loss (avg) 0.5489012633585292, Step Time 236 ms, ETA 3:17
# Step 80/908: Loss (avg) 0.5684826817527987, Step Time 236 ms, ETA 3:15
# Step 90/908: Loss (avg) 0.5917009356670409, Step Time 236 ms, ETA 3:13
# Step 100/908: Loss (avg) 0.6132272614962943, Step Time 237 ms, ETA 3:11
# Step 110/908: Loss (avg) 0.6024505319342205, Step Time 236 ms, ETA 3:8
# Step 120/908: Loss (avg) 0.5702996895582544, Step Time 238 ms, ETA 3:7
# Step 130/908: Loss (avg) 0.5459716024356814, Step Time 238 ms, ETA 3:5
# Step 140/908: Loss (avg) 0.5674450990417814, Step Time 236 ms, ETA 3:1
# Step 150/908: Loss (avg) 0.5432401944219287, Step Time 236 ms, ETA 2:58
# Step 160/908: Loss (avg) 0.5811434977188625, Step Time 237 ms, ETA 2:57
# Step 170/908: Loss (avg) 0.5419553940101542, Step Time 236 ms, ETA 2:54
# Step 180/908: Loss (avg) 0.5565164619336361, Step Time 237 ms, ETA 2:52
# Step 190/908: Loss (avg) 0.6496653025242635, Step Time 238 ms, ETA 2:50
# Step 200/908: Loss (avg) 0.527413271076672, Step Time 236 ms, ETA 2:47
# Step 210/908: Loss (avg) 0.5738768986032026, Step Time 236 ms, ETA 2:44
# Step 220/908: Loss (avg) 0.5409012034836594, Step Time 235 ms, ETA 2:41
# Step 230/908: Loss (avg) 0.5828955641761542, Step Time 237 ms, ETA 2:40
# Step 240/908: Loss (avg) 0.5574844324411088, Step Time 237 ms, ETA 2:38
# Step 250/908: Loss (avg) 0.5259441507322943, Step Time 236 ms, ETA 2:35
# Step 260/908: Loss (avg) 0.60696245048675, Step Time 235 ms, ETA 2:32
# Step 270/908: Loss (avg) 0.660307319236648, Step Time 236 ms, ETA 2:30
# Step 280/908: Loss (avg) 0.554281631630273, Step Time 237 ms, ETA 2:28
# Step 290/908: Loss (avg) 0.625873106561378, Step Time 239 ms, ETA 2:27
# Step 300/908: Loss (avg) 0.5479704006887505, Step Time 237 ms, ETA 2:24
# Step 310/908: Loss (avg) 0.5542777176473935, Step Time 235 ms, ETA 2:20
# Step 320/908: Loss (avg) 0.5751330979593051, Step Time 237 ms, ETA 2:19
# Step 330/908: Loss (avg) 0.5729452386820643, Step Time 237 ms, ETA 2:16
# Step 340/908: Loss (avg) 0.6456523118916778, Step Time 236 ms, ETA 2:14
# Step 350/908: Loss (avg) 0.6036049907488072, Step Time 237 ms, ETA 2:12
# Step 360/908: Loss (avg) 0.5853386642018809, Step Time 237 ms, ETA 2:9
# Step 370/908: Loss (avg) 0.5957037207450218, Step Time 237 ms, ETA 2:7
# Step 380/908: Loss (avg) 0.585895006665502, Step Time 236 ms, ETA 2:4
# Step 390/908: Loss (avg) 0.577711081307722, Step Time 236 ms, ETA 2:2
# Step 400/908: Loss (avg) 0.5996071119298101, Step Time 238 ms, ETA 2:0
# Step 410/908: Loss (avg) 0.6222630079512904, Step Time 238 ms, ETA 1:58
# Step 420/908: Loss (avg) 0.6043350134959817, Step Time 235 ms, ETA 1:54
# Step 430/908: Loss (avg) 0.5821649990093276, Step Time 236 ms, ETA 1:52
# Step 440/908: Loss (avg) 0.5457788399646432, Step Time 237 ms, ETA 1:50
# Step 450/908: Loss (avg) 0.5388267606275103, Step Time 236 ms, ETA 1:48
# Step 460/908: Loss (avg) 0.5433884212793822, Step Time 237 ms, ETA 1:46
# Step 470/908: Loss (avg) 0.5357398527861033, Step Time 236 ms, ETA 1:43
# Step 480/908: Loss (avg) 0.563717042264898, Step Time 236 ms, ETA 1:41
# Step 490/908: Loss (avg) 0.5743863154818002, Step Time 236 ms, ETA 1:38
# Step 500/908: Loss (avg) 0.6024658003659009, Step Time 236 ms, ETA 1:36
# Step 510/908: Loss (avg) 0.508963780994922, Step Time 237 ms, ETA 1:34
# Step 520/908: Loss (avg) 0.48479760395634514, Step Time 237 ms, ETA 1:31
# Step 530/908: Loss (avg) 0.620282729892145, Step Time 237 ms, ETA 1:29
# Step 540/908: Loss (avg) 0.5616994197823902, Step Time 237 ms, ETA 1:27
# Step 550/908: Loss (avg) 0.4902620786117882, Step Time 236 ms, ETA 1:24
# Step 560/908: Loss (avg) 0.46401099285212594, Step Time 237 ms, ETA 1:22
# Step 570/908: Loss (avg) 0.5061209080559974, Step Time 239 ms, ETA 1:20
# Step 580/908: Loss (avg) 0.5170143685699109, Step Time 237 ms, ETA 1:17
# Step 590/908: Loss (avg) 0.5736926160165268, Step Time 236 ms, ETA 1:15
# Step 600/908: Loss (avg) 0.546513989960094, Step Time 236 ms, ETA 1:12
# Step 610/908: Loss (avg) 0.5812062976941512, Step Time 237 ms, ETA 1:10
# Step 620/908: Loss (avg) 0.6377010520173488, Step Time 236 ms, ETA 1:7
# Step 630/908: Loss (avg) 0.6170877079292574, Step Time 238 ms, ETA 1:6
# Step 640/908: Loss (avg) 0.5731784224492544, Step Time 237 ms, ETA 1:3
# Step 650/908: Loss (avg) 0.6466115396865709, Step Time 236 ms, ETA 1:0
# Step 660/908: Loss (avg) 0.6134115662949499, Step Time 236 ms, ETA 0:58
# Step 670/908: Loss (avg) 0.5231523250202936, Step Time 237 ms, ETA 0:56
# Step 680/908: Loss (avg) 0.5482901828513985, Step Time 237 ms, ETA 0:54
# Step 690/908: Loss (avg) 0.57894147497945, Step Time 237 ms, ETA 0:51
# Step 700/908: Loss (avg) 0.5648737815246864, Step Time 236 ms, ETA 0:49
# Step 710/908: Loss (avg) 0.616961661998184, Step Time 236 ms, ETA 0:46
# Step 720/908: Loss (avg) 0.5658029505010881, Step Time 236 ms, ETA 0:44
# Step 730/908: Loss (avg) 0.5599963913171828, Step Time 236 ms, ETA 0:42
# Step 740/908: Loss (avg) 0.5147654825374892, Step Time 237 ms, ETA 0:39
# Step 750/908: Loss (avg) 0.5194388285308256, Step Time 237 ms, ETA 0:37
# Step 760/908: Loss (avg) 0.566054051603709, Step Time 237 ms, ETA 0:35
# Step 770/908: Loss (avg) 0.5744089752900063, Step Time 237 ms, ETA 0:32
# Step 780/908: Loss (avg) 0.5010784586617195, Step Time 235 ms, ETA 0:30
# Step 790/908: Loss (avg) 0.5551917564721713, Step Time 237 ms, ETA 0:27
# Step 800/908: Loss (avg) 0.5224815694838355, Step Time 238 ms, ETA 0:25
# Step 810/908: Loss (avg) 0.5444716191025035, Step Time 236 ms, ETA 0:23
# Step 820/908: Loss (avg) 0.57461765509949, Step Time 236 ms, ETA 0:20
# Step 830/908: Loss (avg) 0.6338798355389768, Step Time 236 ms, ETA 0:18
# Step 840/908: Loss (avg) 0.5958351181819124, Step Time 236 ms, ETA 0:16
# Step 850/908: Loss (avg) 0.6198206810324617, Step Time 236 ms, ETA 0:13
# Step 860/908: Loss (avg) 0.5576816104828929, Step Time 237 ms, ETA 0:11
# Step 870/908: Loss (avg) 0.5423799266245226, Step Time 237 ms, ETA 0:9
# Step 880/908: Loss (avg) 0.5727447776359791, Step Time 237 ms, ETA 0:6
# Step 890/908: Loss (avg) 0.633369066951611, Step Time 237 ms, ETA 0:4
# Step 900/908: Loss (avg) 0.518446211711927, Step Time 235 ms, ETA 0:1
# Metrics for test set:
#    accuracy        f1  precision    recall  specificity     auroc      aupr  \
# 0  0.720072  0.776556   0.759192  0.794733     0.602273  0.698503  0.839781
#
#               confusion_matrix
# 0  [[1696, 1120], [912, 3531]]
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# Step 10/908: Loss (avg) 0.46104800058353607, Step Time 721 ms, ETA 10:47
# Step 20/908: Loss (avg) 0.6214307571317408, Step Time 723 ms, ETA 10:42
# Step 30/908: Loss (avg) 0.67089142811695, Step Time 727 ms, ETA 10:38
# Step 40/908: Loss (avg) 0.6623514526677019, Step Time 726 ms, ETA 10:30
# Step 50/908: Loss (avg) 0.6627527532756321, Step Time 728 ms, ETA 10:24
# Step 60/908: Loss (avg) 0.6184575164099484, Step Time 727 ms, ETA 10:16
# Step 70/908: Loss (avg) 0.5972468489946764, Step Time 729 ms, ETA 10:10
# Step 80/908: Loss (avg) 0.6008107506189616, Step Time 727 ms, ETA 10:1
# Step 90/908: Loss (avg) 0.5715387320418719, Step Time 726 ms, ETA 9:53
# Step 100/908: Loss (avg) 0.5602891845906534, Step Time 733 ms, ETA 9:52
# Step 110/908: Loss (avg) 0.5768482753857085, Step Time 729 ms, ETA 9:41
# Step 120/908: Loss (avg) 0.6197724956434973, Step Time 731 ms, ETA 9:36
# Step 130/908: Loss (avg) 0.5746439592983679, Step Time 730 ms, ETA 9:27
# Step 140/908: Loss (avg) 0.5641141711203085, Step Time 723 ms, ETA 9:15
# Step 150/908: Loss (avg) 0.5962955341125172, Step Time 733 ms, ETA 9:15
# Step 160/908: Loss (avg) 0.5949657779751882, Step Time 733 ms, ETA 9:8
# Step 170/908: Loss (avg) 0.5392432376776042, Step Time 731 ms, ETA 8:59
# Step 180/908: Loss (avg) 0.5101240499229258, Step Time 731 ms, ETA 8:52
# Step 190/908: Loss (avg) 0.48018490463480223, Step Time 731 ms, ETA 8:44
# Step 200/908: Loss (avg) 0.48081408088084376, Step Time 734 ms, ETA 8:39
# Step 210/908: Loss (avg) 0.47481300814410315, Step Time 732 ms, ETA 8:30
# Step 220/908: Loss (avg) 0.5665048738333497, Step Time 731 ms, ETA 8:22
# Step 230/908: Loss (avg) 0.6054816425107213, Step Time 731 ms, ETA 8:15
# Step 240/908: Loss (avg) 0.6277693672383005, Step Time 734 ms, ETA 8:10
# Step 250/908: Loss (avg) 0.694397337394037, Step Time 733 ms, ETA 8:2
# Step 260/908: Loss (avg) 0.6190689144058696, Step Time 731 ms, ETA 7:53
# Step 270/908: Loss (avg) 0.6465107979171221, Step Time 733 ms, ETA 7:47
# Step 280/908: Loss (avg) 0.5489940145521359, Step Time 732 ms, ETA 7:39
# Step 290/908: Loss (avg) 0.5799754400586782, Step Time 734 ms, ETA 7:33
# Step 300/908: Loss (avg) 0.5559479281234265, Step Time 733 ms, ETA 7:25
# Step 310/908: Loss (avg) 0.6384861085382781, Step Time 730 ms, ETA 7:16
# Step 320/908: Loss (avg) 0.5698478545481728, Step Time 732 ms, ETA 7:10
# Step 330/908: Loss (avg) 0.4733682088748051, Step Time 726 ms, ETA 6:59
# Step 340/908: Loss (avg) 0.4913240298935177, Step Time 736 ms, ETA 6:58
# Step 350/908: Loss (avg) 0.523192205261359, Step Time 732 ms, ETA 6:48
# Step 360/908: Loss (avg) 0.533167592354616, Step Time 732 ms, ETA 6:41
# Step 370/908: Loss (avg) 0.5403838927738356, Step Time 731 ms, ETA 6:33
# Step 380/908: Loss (avg) 0.5735198216169397, Step Time 731 ms, ETA 6:25
# Step 390/908: Loss (avg) 0.519113569424974, Step Time 734 ms, ETA 6:20
# Step 400/908: Loss (avg) 0.5200804004105781, Step Time 733 ms, ETA 6:12
# Step 410/908: Loss (avg) 0.500667263632427, Step Time 730 ms, ETA 6:3
# Step 420/908: Loss (avg) 0.4763171670605253, Step Time 733 ms, ETA 5:57
# Step 430/908: Loss (avg) 0.5326629817102634, Step Time 732 ms, ETA 5:49
# Step 440/908: Loss (avg) 0.5463113076693453, Step Time 731 ms, ETA 5:42
# Step 450/908: Loss (avg) 0.5312529161381876, Step Time 733 ms, ETA 5:35
# Step 460/908: Loss (avg) 0.5176184291808773, Step Time 733 ms, ETA 5:28
# Step 470/908: Loss (avg) 0.5733776455514844, Step Time 733 ms, ETA 5:21
# Step 480/908: Loss (avg) 0.573548123387233, Step Time 732 ms, ETA 5:13
# Step 490/908: Loss (avg) 0.5358548975979456, Step Time 732 ms, ETA 5:5
# Step 500/908: Loss (avg) 0.5345970918290411, Step Time 732 ms, ETA 4:58
# Step 510/908: Loss (avg) 0.49929847618913237, Step Time 733 ms, ETA 4:51
# Step 520/908: Loss (avg) 0.5009563649605724, Step Time 733 ms, ETA 4:44
# Step 530/908: Loss (avg) 0.5059669954911614, Step Time 734 ms, ETA 4:37
# Step 540/908: Loss (avg) 0.5327100893789957, Step Time 732 ms, ETA 4:29
# Step 550/908: Loss (avg) 0.594960615956968, Step Time 733 ms, ETA 4:22
# Step 560/908: Loss (avg) 0.5273143244194959, Step Time 733 ms, ETA 4:15
# Step 570/908: Loss (avg) 0.5044086742706048, Step Time 734 ms, ETA 4:8
# Step 580/908: Loss (avg) 0.5635393252704934, Step Time 732 ms, ETA 4:0
# Step 590/908: Loss (avg) 0.4905629218271062, Step Time 733 ms, ETA 3:53
# Step 600/908: Loss (avg) 0.5490859770768887, Step Time 733 ms, ETA 3:45
# Step 610/908: Loss (avg) 0.5695638498728265, Step Time 733 ms, ETA 3:38
# Step 620/908: Loss (avg) 0.5430628170292002, Step Time 733 ms, ETA 3:31
# Step 630/908: Loss (avg) 0.5744194551595964, Step Time 732 ms, ETA 3:23
# Step 640/908: Loss (avg) 0.5968139217712625, Step Time 731 ms, ETA 3:15
# Step 650/908: Loss (avg) 0.48728199619274776, Step Time 735 ms, ETA 3:9
# Step 660/908: Loss (avg) 0.5245162368622216, Step Time 734 ms, ETA 3:2
# Step 670/908: Loss (avg) 0.5435837322006263, Step Time 731 ms, ETA 2:53
# Step 680/908: Loss (avg) 0.5718070554861271, Step Time 731 ms, ETA 2:46
# Step 690/908: Loss (avg) 0.5606503870025394, Step Time 732 ms, ETA 2:39
# Step 700/908: Loss (avg) 0.49632363266998486, Step Time 733 ms, ETA 2:32
# Step 710/908: Loss (avg) 0.4503323860868534, Step Time 732 ms, ETA 2:24
# Step 720/908: Loss (avg) 0.4771577351682006, Step Time 731 ms, ETA 2:17
# Step 730/908: Loss (avg) 0.5749172540185855, Step Time 732 ms, ETA 2:10
# Step 740/908: Loss (avg) 0.5108287532218321, Step Time 733 ms, ETA 2:3
# Step 750/908: Loss (avg) 0.49118686048326554, Step Time 732 ms, ETA 1:55
# Step 760/908: Loss (avg) 0.4877971173360366, Step Time 732 ms, ETA 1:48
# Step 770/908: Loss (avg) 0.501361375166844, Step Time 734 ms, ETA 1:41
# Step 780/908: Loss (avg) 0.4965255554231038, Step Time 732 ms, ETA 1:33
# Step 790/908: Loss (avg) 0.5213338524495394, Step Time 735 ms, ETA 1:26
# Step 800/908: Loss (avg) 0.5610238773349835, Step Time 734 ms, ETA 1:19
# Step 810/908: Loss (avg) 0.4835966075804177, Step Time 731 ms, ETA 1:11
# Step 820/908: Loss (avg) 0.5099383113041306, Step Time 733 ms, ETA 1:4
# Step 830/908: Loss (avg) 0.5210142589692482, Step Time 734 ms, ETA 0:57
# Step 840/908: Loss (avg) 0.5101437166034145, Step Time 732 ms, ETA 0:49
# Step 850/908: Loss (avg) 0.5145834292732635, Step Time 732 ms, ETA 0:42
# Step 860/908: Loss (avg) 0.4339856098456881, Step Time 735 ms, ETA 0:35
# Step 870/908: Loss (avg) 0.44483672959208487, Step Time 733 ms, ETA 0:27
# Step 880/908: Loss (avg) 0.5367179769679075, Step Time 732 ms, ETA 0:20
# Step 890/908: Loss (avg) 0.5343536735438782, Step Time 736 ms, ETA 0:13
# Step 900/908: Loss (avg) 0.4818867670540137, Step Time 733 ms, ETA 0:5
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# Step 10/908: Loss (avg) 0.3814550679962804, Step Time 234 ms, ETA 3:30
# Step 20/908: Loss (avg) 0.5073996631751088, Step Time 235 ms, ETA 3:28
# Step 30/908: Loss (avg) 0.5101155785722854, Step Time 235 ms, ETA 3:26
# Step 40/908: Loss (avg) 0.539511069151562, Step Time 237 ms, ETA 3:25
# Step 50/908: Loss (avg) 0.520356519021117, Step Time 237 ms, ETA 3:23
# Step 60/908: Loss (avg) 0.5451938037002031, Step Time 237 ms, ETA 3:20
# Step 70/908: Loss (avg) 0.4896360870484252, Step Time 237 ms, ETA 3:18
# Step 80/908: Loss (avg) 0.5463311447936983, Step Time 237 ms, ETA 3:16
# Step 90/908: Loss (avg) 0.5367023606906033, Step Time 237 ms, ETA 3:13
# Step 100/908: Loss (avg) 0.6513136414696961, Step Time 238 ms, ETA 3:12
# Step 110/908: Loss (avg) 0.6536373613231541, Step Time 236 ms, ETA 3:8
# Step 120/908: Loss (avg) 0.6055737241626601, Step Time 236 ms, ETA 3:5
# Step 130/908: Loss (avg) 0.5386597485837614, Step Time 235 ms, ETA 3:2
# Step 140/908: Loss (avg) 0.6093976682239913, Step Time 238 ms, ETA 3:2
# Step 150/908: Loss (avg) 0.6054261779190241, Step Time 236 ms, ETA 2:58
# Step 160/908: Loss (avg) 0.6006624287795532, Step Time 236 ms, ETA 2:56
# Step 170/908: Loss (avg) 0.5741650726324781, Step Time 238 ms, ETA 2:55
# Step 180/908: Loss (avg) 0.5970966880707932, Step Time 236 ms, ETA 2:51
# Step 190/908: Loss (avg) 0.5157169397382428, Step Time 238 ms, ETA 2:50
# Step 200/908: Loss (avg) 0.5510924611072039, Step Time 236 ms, ETA 2:47
# Step 210/908: Loss (avg) 0.47691896345809276, Step Time 235 ms, ETA 2:44
# Step 220/908: Loss (avg) 0.4111345857658992, Step Time 236 ms, ETA 2:42
# Step 230/908: Loss (avg) 0.4495839889966178, Step Time 235 ms, ETA 2:39
# Step 240/908: Loss (avg) 0.500647615341613, Step Time 236 ms, ETA 2:37
# Step 250/908: Loss (avg) 0.49860337747562794, Step Time 235 ms, ETA 2:34
# Step 260/908: Loss (avg) 0.5178102828945318, Step Time 235 ms, ETA 2:32
# Step 270/908: Loss (avg) 0.6063568478424859, Step Time 235 ms, ETA 2:29
# Step 280/908: Loss (avg) 0.5781372727865782, Step Time 237 ms, ETA 2:28
# Step 290/908: Loss (avg) 0.5481480933871943, Step Time 238 ms, ETA 2:27
# Step 300/908: Loss (avg) 0.4711072134004641, Step Time 236 ms, ETA 2:23
# Step 310/908: Loss (avg) 0.521970954211548, Step Time 236 ms, ETA 2:21
# Step 320/908: Loss (avg) 0.4553492352232569, Step Time 236 ms, ETA 2:18
# Step 330/908: Loss (avg) 0.5206494413631856, Step Time 238 ms, ETA 2:17
# Step 340/908: Loss (avg) 0.5493385133025076, Step Time 238 ms, ETA 2:15
# Step 350/908: Loss (avg) 0.573949339856682, Step Time 237 ms, ETA 2:12
# Step 360/908: Loss (avg) 0.5983570990918211, Step Time 237 ms, ETA 2:9
# Step 370/908: Loss (avg) 0.5692721093780779, Step Time 237 ms, ETA 2:7
# Step 380/908: Loss (avg) 0.5624720834902968, Step Time 236 ms, ETA 2:4
# Step 390/908: Loss (avg) 0.5206786080248814, Step Time 236 ms, ETA 2:2
# Step 400/908: Loss (avg) 0.5172373271586264, Step Time 236 ms, ETA 1:59
# Step 410/908: Loss (avg) 0.5795124822874638, Step Time 236 ms, ETA 1:57
# Step 420/908: Loss (avg) 0.5809239295759734, Step Time 237 ms, ETA 1:55
# Step 430/908: Loss (avg) 0.607296996574541, Step Time 237 ms, ETA 1:53
# Step 440/908: Loss (avg) 0.5321454430999318, Step Time 237 ms, ETA 1:50
# Step 450/908: Loss (avg) 0.5131027276732607, Step Time 238 ms, ETA 1:49
# Step 460/908: Loss (avg) 0.476324132652858, Step Time 237 ms, ETA 1:46
# Step 470/908: Loss (avg) 0.537087806579359, Step Time 237 ms, ETA 1:43
# Step 480/908: Loss (avg) 0.5652747662660605, Step Time 236 ms, ETA 1:41
# Step 490/908: Loss (avg) 0.5229344498861156, Step Time 235 ms, ETA 1:38
# Step 500/908: Loss (avg) 0.5133030413968629, Step Time 237 ms, ETA 1:36
# Step 510/908: Loss (avg) 0.6104530337739105, Step Time 237 ms, ETA 1:34
# Step 520/908: Loss (avg) 0.5363167635815727, Step Time 236 ms, ETA 1:31
# Step 530/908: Loss (avg) 0.4742663506910815, Step Time 236 ms, ETA 1:29
# Step 540/908: Loss (avg) 0.4525155032744723, Step Time 236 ms, ETA 1:26
# Step 550/908: Loss (avg) 0.5495442522142946, Step Time 237 ms, ETA 1:24
# Step 560/908: Loss (avg) 0.45656206172734237, Step Time 236 ms, ETA 1:22
# Step 570/908: Loss (avg) 0.5151142794403747, Step Time 235 ms, ETA 1:19
# Step 580/908: Loss (avg) 0.6136112127783924, Step Time 235 ms, ETA 1:17
# Step 590/908: Loss (avg) 0.6193832703015549, Step Time 235 ms, ETA 1:14
# Step 600/908: Loss (avg) 0.5352197651178341, Step Time 238 ms, ETA 1:13
# Step 610/908: Loss (avg) 0.5436402748616442, Step Time 238 ms, ETA 1:10
# Step 620/908: Loss (avg) 0.5483586905638691, Step Time 237 ms, ETA 1:8
# Step 630/908: Loss (avg) 0.592390798696105, Step Time 236 ms, ETA 1:5
# Step 640/908: Loss (avg) 0.6184878772704937, Step Time 236 ms, ETA 1:3
# Step 650/908: Loss (avg) 0.5907215511477683, Step Time 236 ms, ETA 1:0
# Step 660/908: Loss (avg) 0.5514079362306097, Step Time 236 ms, ETA 0:58
# Step 670/908: Loss (avg) 0.5189788602930823, Step Time 236 ms, ETA 0:56
# Step 680/908: Loss (avg) 0.5337443693169317, Step Time 236 ms, ETA 0:53
# Step 690/908: Loss (avg) 0.5074990224038018, Step Time 235 ms, ETA 0:51
# Step 700/908: Loss (avg) 0.5307141623603919, Step Time 236 ms, ETA 0:49
# Step 710/908: Loss (avg) 0.5398410946041997, Step Time 236 ms, ETA 0:46
# Step 720/908: Loss (avg) 0.5846343560767593, Step Time 236 ms, ETA 0:44
# Step 730/908: Loss (avg) 0.654572758521014, Step Time 236 ms, ETA 0:42
# Step 740/908: Loss (avg) 0.6165607938619878, Step Time 236 ms, ETA 0:39
# Step 750/908: Loss (avg) 0.6009137938948846, Step Time 236 ms, ETA 0:37
# Step 760/908: Loss (avg) 0.5731795071238984, Step Time 238 ms, ETA 0:35
# Step 770/908: Loss (avg) 0.5389373897873643, Step Time 236 ms, ETA 0:32
# Step 780/908: Loss (avg) 0.5180757693338525, Step Time 235 ms, ETA 0:30
# Step 790/908: Loss (avg) 0.5480668098145628, Step Time 236 ms, ETA 0:27
# Step 800/908: Loss (avg) 0.5411633276573974, Step Time 235 ms, ETA 0:25
# Step 810/908: Loss (avg) 0.5441871348170159, Step Time 236 ms, ETA 0:23
# Step 820/908: Loss (avg) 0.5066861815182042, Step Time 236 ms, ETA 0:20
# Step 830/908: Loss (avg) 0.5000800703963993, Step Time 236 ms, ETA 0:18
# Step 840/908: Loss (avg) 0.6054367765325152, Step Time 236 ms, ETA 0:16
# Step 850/908: Loss (avg) 0.6256417006250126, Step Time 236 ms, ETA 0:13
# Step 860/908: Loss (avg) 0.5594464544771048, Step Time 238 ms, ETA 0:11
# Step 870/908: Loss (avg) 0.5832994091229583, Step Time 236 ms, ETA 0:8
# Step 880/908: Loss (avg) 0.5614690765798624, Step Time 236 ms, ETA 0:6
# Step 890/908: Loss (avg) 0.5577460590716627, Step Time 236 ms, ETA 0:4
# Step 900/908: Loss (avg) 0.5773258259146359, Step Time 236 ms, ETA 0:1
# Metrics for test set:
# ...
# Step 740/908: Loss (avg) 0.42333264680097554, Step Time 734 ms, ETA 2:3
# Step 750/908: Loss (avg) 0.39880292748364954, Step Time 735 ms, ETA 1:56
# Step 760/908: Loss (avg) 0.4007847236809186, Step Time 734 ms, ETA 1:48
# Step 770/908: Loss (avg) 0.46699934746528277, Step Time 732 ms, ETA 1:41
# Step 780/908: Loss (avg) 0.35554907079315473, Step Time 735 ms, ETA 1:34
# Step 790/908: Loss (avg) 0.44818038248567776, Step Time 733 ms, ETA 1:26
# Step 800/908: Loss (avg) 0.5055653673097751, Step Time 734 ms, ETA 1:19
# Step 810/908: Loss (avg) 0.4113431369785772, Step Time 734 ms, ETA 1:11
# Step 820/908: Loss (avg) 0.40829738982887115, Step Time 734 ms, ETA 1:4
# Step 830/908: Loss (avg) 0.4069070256903611, Step Time 733 ms, ETA 0:57
# Step 840/908: Loss (avg) 0.41169190858090504, Step Time 737 ms, ETA 0:50
# Step 850/908: Loss (avg) 0.3893900108105395, Step Time 733 ms, ETA 0:42
# Step 860/908: Loss (avg) 0.4549066502311571, Step Time 732 ms, ETA 0:35
# Step 870/908: Loss (avg) 0.34859294250460576, Step Time 732 ms, ETA 0:27
# Step 880/908: Loss (avg) 0.3842651597157377, Step Time 731 ms, ETA 0:20
# Step 890/908: Loss (avg) 0.46801987116690724, Step Time 734 ms, ETA 0:13
# Step 900/908: Loss (avg) 0.41923935763791625, Step Time 733 ms, ETA 0:5
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# Step 10/908: Loss (avg) 0.3500099364987468, Step Time 236 ms, ETA 3:31
# Step 20/908: Loss (avg) 0.433734148164418, Step Time 237 ms, ETA 3:30
# Step 30/908: Loss (avg) 0.4985383816966382, Step Time 237 ms, ETA 3:28
# Step 40/908: Loss (avg) 0.4192331545945731, Step Time 236 ms, ETA 3:24
# Step 50/908: Loss (avg) 0.5346926628011162, Step Time 238 ms, ETA 3:24
# Step 60/908: Loss (avg) 0.6184456730545979, Step Time 237 ms, ETA 3:20
# Step 70/908: Loss (avg) 0.46760898295613296, Step Time 235 ms, ETA 3:16
# Step 80/908: Loss (avg) 0.4601744168904443, Step Time 236 ms, ETA 3:15
# Step 90/908: Loss (avg) 0.6240028017019893, Step Time 236 ms, ETA 3:13
# Step 100/908: Loss (avg) 0.45064811496972257, Step Time 236 ms, ETA 3:10
# Step 110/908: Loss (avg) 0.43484913975671485, Step Time 238 ms, ETA 3:9
# Step 120/908: Loss (avg) 0.46108216456125123, Step Time 237 ms, ETA 3:6
# Step 130/908: Loss (avg) 0.5742078695628556, Step Time 236 ms, ETA 3:3
# Step 140/908: Loss (avg) 0.6360240883738573, Step Time 235 ms, ETA 3:0
# Step 150/908: Loss (avg) 0.5717811914882898, Step Time 237 ms, ETA 2:59
# Step 160/908: Loss (avg) 0.6217068691285331, Step Time 238 ms, ETA 2:58
# Step 170/908: Loss (avg) 0.621776062595304, Step Time 237 ms, ETA 2:54
# Step 180/908: Loss (avg) 0.6463862124437522, Step Time 236 ms, ETA 2:51
# Step 190/908: Loss (avg) 0.5169665955225516, Step Time 237 ms, ETA 2:50
# Step 200/908: Loss (avg) 0.5730516963635364, Step Time 236 ms, ETA 2:47
# Step 210/908: Loss (avg) 0.5571220690132296, Step Time 236 ms, ETA 2:44
# Step 220/908: Loss (avg) 0.5516948944528348, Step Time 239 ms, ETA 2:44
# Step 230/908: Loss (avg) 0.4192152201081545, Step Time 236 ms, ETA 2:40
# Step 240/908: Loss (avg) 0.6004877614290229, Step Time 236 ms, ETA 2:37
# Step 250/908: Loss (avg) 0.48988513816774065, Step Time 236 ms, ETA 2:35
# Step 260/908: Loss (avg) 0.5484483707761001, Step Time 236 ms, ETA 2:32
# Step 270/908: Loss (avg) 0.5302931246866525, Step Time 237 ms, ETA 2:31
# Step 280/908: Loss (avg) 0.5705206358184265, Step Time 237 ms, ETA 2:28
# Step 290/908: Loss (avg) 0.6579526072804409, Step Time 236 ms, ETA 2:25
# Step 300/908: Loss (avg) 0.6508936285934017, Step Time 238 ms, ETA 2:24
# Step 310/908: Loss (avg) 0.68625431909539, Step Time 236 ms, ETA 2:21
# Step 320/908: Loss (avg) 0.7836800491710747, Step Time 236 ms, ETA 2:18
# Step 330/908: Loss (avg) 0.6483042515861834, Step Time 236 ms, ETA 2:16
# Step 340/908: Loss (avg) 0.6522677519812881, Step Time 239 ms, ETA 2:15
# Step 350/908: Loss (avg) 0.6588979943164412, Step Time 237 ms, ETA 2:12
# Step 360/908: Loss (avg) 0.4746506974408831, Step Time 236 ms, ETA 2:9
# Step 370/908: Loss (avg) 0.5108123119629026, Step Time 236 ms, ETA 2:6
# Step 380/908: Loss (avg) 0.6097797256638862, Step Time 237 ms, ETA 2:5
# Step 390/908: Loss (avg) 0.5702029610972877, Step Time 236 ms, ETA 2:2
# Step 400/908: Loss (avg) 0.650864700097169, Step Time 238 ms, ETA 2:0
# Step 410/908: Loss (avg) 0.617936431257768, Step Time 237 ms, ETA 1:58
# Step 420/908: Loss (avg) 0.5582099449898047, Step Time 235 ms, ETA 1:54
# Step 430/908: Loss (avg) 0.49864562730382767, Step Time 237 ms, ETA 1:53
# Step 440/908: Loss (avg) 0.5268745127073896, Step Time 237 ms, ETA 1:50
# Step 450/908: Loss (avg) 0.5481477586607355, Step Time 236 ms, ETA 1:48
# Step 460/908: Loss (avg) 0.4668188192001481, Step Time 237 ms, ETA 1:46
# Step 470/908: Loss (avg) 0.6117938969029597, Step Time 237 ms, ETA 1:43
# Step 480/908: Loss (avg) 0.6005645416577903, Step Time 237 ms, ETA 1:41
# Step 490/908: Loss (avg) 0.5222230423515563, Step Time 236 ms, ETA 1:38
# Step 500/908: Loss (avg) 0.6449821198855618, Step Time 237 ms, ETA 1:36
# Step 510/908: Loss (avg) 0.4792349826162392, Step Time 236 ms, ETA 1:33
# Step 520/908: Loss (avg) 0.6353218946912107, Step Time 237 ms, ETA 1:31
# Step 530/908: Loss (avg) 0.5507169200374743, Step Time 236 ms, ETA 1:29
# Step 540/908: Loss (avg) 0.5472159313501562, Step Time 236 ms, ETA 1:26
# Step 550/908: Loss (avg) 0.5483632018799236, Step Time 236 ms, ETA 1:24
# Step 560/908: Loss (avg) 0.4977319376029767, Step Time 237 ms, ETA 1:22
# Step 570/908: Loss (avg) 0.6550315822757826, Step Time 236 ms, ETA 1:19
# Step 580/908: Loss (avg) 0.6564492228917375, Step Time 239 ms, ETA 1:18
# Step 590/908: Loss (avg) 0.6563904239672079, Step Time 237 ms, ETA 1:15
# Step 600/908: Loss (avg) 0.6875121920243997, Step Time 235 ms, ETA 1:12
# Step 610/908: Loss (avg) 0.5766552714063593, Step Time 237 ms, ETA 1:10
# Step 620/908: Loss (avg) 0.5290944415394232, Step Time 236 ms, ETA 1:7
# Step 630/908: Loss (avg) 0.6408497602563731, Step Time 237 ms, ETA 1:5
# Step 640/908: Loss (avg) 0.5136784574423069, Step Time 239 ms, ETA 1:4
# Step 650/908: Loss (avg) 0.6170565979766809, Step Time 242 ms, ETA 1:2
# Step 660/908: Loss (avg) 0.5874808380108921, Step Time 237 ms, ETA 0:58
# Step 670/908: Loss (avg) 0.5386493628434964, Step Time 236 ms, ETA 0:56
# Step 680/908: Loss (avg) 0.6370841004870127, Step Time 237 ms, ETA 0:54
# Step 690/908: Loss (avg) 0.6831898311967584, Step Time 236 ms, ETA 0:51
# Step 700/908: Loss (avg) 0.6518515933935635, Step Time 236 ms, ETA 0:49
# Step 710/908: Loss (avg) 0.535478618291966, Step Time 236 ms, ETA 0:46
# Step 720/908: Loss (avg) 0.5954114855889151, Step Time 237 ms, ETA 0:44
# Step 730/908: Loss (avg) 0.5827586373150403, Step Time 237 ms, ETA 0:42
# Step 740/908: Loss (avg) 0.5620641817668021, Step Time 236 ms, ETA 0:39
# Step 750/908: Loss (avg) 0.5562079015997183, Step Time 238 ms, ETA 0:37
# Step 760/908: Loss (avg) 0.5870882865434482, Step Time 237 ms, ETA 0:35
# Step 770/908: Loss (avg) 0.5215316473088557, Step Time 237 ms, ETA 0:32
# Step 780/908: Loss (avg) 0.516452644486586, Step Time 237 ms, ETA 0:30
# Step 790/908: Loss (avg) 0.6575867775901764, Step Time 237 ms, ETA 0:27
# Step 800/908: Loss (avg) 0.524541567816835, Step Time 237 ms, ETA 0:25
# Step 810/908: Loss (avg) 0.5060529979480782, Step Time 237 ms, ETA 0:23
# Step 820/908: Loss (avg) 0.5108243742758836, Step Time 236 ms, ETA 0:20
# Step 830/908: Loss (avg) 0.5709385477163035, Step Time 238 ms, ETA 0:18
# Step 840/908: Loss (avg) 0.5617612250828019, Step Time 237 ms, ETA 0:16
# Step 850/908: Loss (avg) 0.6167352476676339, Step Time 237 ms, ETA 0:13
# Step 860/908: Loss (avg) 0.5434377465653645, Step Time 236 ms, ETA 0:11
# Step 870/908: Loss (avg) 0.6517226733286468, Step Time 236 ms, ETA 0:8
# Step 880/908: Loss (avg) 0.5369319411952046, Step Time 237 ms, ETA 0:6
# Step 890/908: Loss (avg) 0.6163479859398476, Step Time 237 ms, ETA 0:4
# Step 900/908: Loss (avg) 0.49137939400433805, Step Time 236 ms, ETA 0:1
# Metrics for test set:
#    accuracy        f1  precision    recall  specificity     auroc      aupr  \
# 0  0.753547  0.810788   0.764765  0.862705     0.581321  0.722013  0.855752
#
#               confusion_matrix
# 0  [[1637, 1179], [610, 3833]]
# Step 10/908: Loss (avg) 0.44013335507878737, Step Time 722 ms, ETA 10:48
# Step 20/908: Loss (avg) 0.5547575988940044, Step Time 727 ms, ETA 10:45
# Step 30/908: Loss (avg) 0.5901410976170505, Step Time 725 ms, ETA 10:36
# Step 40/908: Loss (avg) 0.5721283854806416, Step Time 727 ms, ETA 10:31
# Step 50/908: Loss (avg) 0.5690262191831332, Step Time 728 ms, ETA 10:24
# Step 60/908: Loss (avg) 0.5279256265771882, Step Time 730 ms, ETA 10:19
# Step 70/908: Loss (avg) 0.4888702437042335, Step Time 731 ms, ETA 10:12
# Step 80/908: Loss (avg) 0.5093638462435326, Step Time 731 ms, ETA 10:5
# Step 90/908: Loss (avg) 0.4904983091039209, Step Time 729 ms, ETA 9:56
# Step 100/908: Loss (avg) 0.5193628895725454, Step Time 731 ms, ETA 9:50
# Step 110/908: Loss (avg) 0.45559979189634864, Step Time 730 ms, ETA 9:42
# Step 120/908: Loss (avg) 0.4422545704618916, Step Time 731 ms, ETA 9:36
# Step 130/908: Loss (avg) 0.40942278832279744, Step Time 733 ms, ETA 9:30
# Step 140/908: Loss (avg) 0.3905136539027207, Step Time 732 ms, ETA 9:22
# Step 150/908: Loss (avg) 0.4706396842008986, Step Time 732 ms, ETA 9:14
# Step 160/908: Loss (avg) 0.3753560592615942, Step Time 732 ms, ETA 9:7
# Step 170/908: Loss (avg) 0.4796007953425921, Step Time 734 ms, ETA 9:1
# Step 180/908: Loss (avg) 0.46624986686352826, Step Time 732 ms, ETA 8:52
# Step 190/908: Loss (avg) 0.45899101966105593, Step Time 738 ms, ETA 8:49
# Step 200/908: Loss (avg) 0.41459812155627657, Step Time 730 ms, ETA 8:36
# Step 210/908: Loss (avg) 0.4095205482679049, Step Time 735 ms, ETA 8:33
# Step 220/908: Loss (avg) 0.4064761310325546, Step Time 736 ms, ETA 8:26
# Step 230/908: Loss (avg) 0.39634813497510735, Step Time 736 ms, ETA 8:19
# Step 240/908: Loss (avg) 0.3948357660584068, Step Time 733 ms, ETA 8:9
# Step 250/908: Loss (avg) 0.44574182006809543, Step Time 731 ms, ETA 8:0
# Step 260/908: Loss (avg) 0.460991282695562, Step Time 735 ms, ETA 7:56
# Step 270/908: Loss (avg) 0.5321068077974156, Step Time 734 ms, ETA 7:48
# Step 280/908: Loss (avg) 0.4735087767057905, Step Time 734 ms, ETA 7:40
# Step 290/908: Loss (avg) 0.4245886460626858, Step Time 733 ms, ETA 7:32
# Step 300/908: Loss (avg) 0.44885697150319903, Step Time 733 ms, ETA 7:25
# Step 310/908: Loss (avg) 0.4790157861894115, Step Time 732 ms, ETA 7:17
# Step 320/908: Loss (avg) 0.3587089068367414, Step Time 733 ms, ETA 7:11
# Step 330/908: Loss (avg) 0.3773223011288272, Step Time 732 ms, ETA 7:3
# Step 340/908: Loss (avg) 0.38584578066769687, Step Time 734 ms, ETA 6:56
# Step 350/908: Loss (avg) 0.38717664928519946, Step Time 732 ms, ETA 6:48
# Step 360/908: Loss (avg) 0.47785714598267015, Step Time 724 ms, ETA 6:36
# Step 370/908: Loss (avg) 0.39190370881478553, Step Time 735 ms, ETA 6:35
# Step 380/908: Loss (avg) 0.4713780302489315, Step Time 733 ms, ETA 6:27
# Step 390/908: Loss (avg) 0.4042632250901978, Step Time 732 ms, ETA 6:19
# Step 400/908: Loss (avg) 0.42801507173037023, Step Time 734 ms, ETA 6:12
# Step 410/908: Loss (avg) 0.37427926125664784, Step Time 734 ms, ETA 6:5
# Step 420/908: Loss (avg) 0.46786516896602803, Step Time 733 ms, ETA 5:57
# Step 430/908: Loss (avg) 0.4041565065154662, Step Time 735 ms, ETA 5:51
# Step 440/908: Loss (avg) 0.41288059435215624, Step Time 733 ms, ETA 5:43
# Step 450/908: Loss (avg) 0.4705499999762601, Step Time 733 ms, ETA 5:35
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-d85ee206e407> in <module>
#       4
#       5 for i in range(5):
# ----> 6     test_metrics_no_biochem = train_with_cols([])
#       7     test_metrics_no_biochem.to_csv(f'./newdata_results/test_metrics_no_biochem({i}).csv')
#       8
#
# <ipython-input-4-96a88a83a50b> in train_with_cols(biochem_cols)
#      18
#      19     for i in range(EPOCHS):
# ---> 20         train_model(multi_gpu_bert_pred, train_dataloader, CrossEntropyLoss(), optimizer, scheduler, True)
#      21
#      22     # Obtener las métricas de validacion
#
# ~/Escritorio/MyGit/AMP-BERT-BIOCHEM/pipeline_tools.py in train_model(model, data_loader, loss_fn, optimizer, scheduler, verbose)
#     144         # Clip the gradients of the model to prevent exploding gradients using clip_grad_norm
#     145         torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm = 1.0)
# --> 146         optimizer.step()
#     147         scheduler.step()
#     148         optimizer.zero_grad()
#
# ~/.local/lib/python3.7/site-packages/torch/optim/lr_scheduler.py in wrapper(*args, **kwargs)
#      66                 instance._step_count += 1
#      67                 wrapped = func.__get__(instance, cls)
# ---> 68                 return wrapped(*args, **kwargs)
#      69
#      70             # Note that the returned function here is no longer a bound method,
#
# ~/.local/lib/python3.7/site-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     138                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     139                 with torch.autograd.profiler.record_function(profile_name):
# --> 140                     out = func(*args, **kwargs)
#     141                     obj._optimizer_step_code()
#     142                     return out
#
# ~/.local/lib/python3.7/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# ~/.local/lib/python3.7/site-packages/torch/optim/adamw.py in step(self, closure)
#     174                   maximize=group['maximize'],
#     175                   foreach=group['foreach'],
# --> 176                   capturable=group['capturable'])
#     177
#     178         return loss
#
# ~/.local/lib/python3.7/site-packages/torch/optim/adamw.py in adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     230          eps=eps,
#     231          maximize=maximize,
# --> 232          capturable=capturable)
#     233
#     234
#
# ~/.local/lib/python3.7/site-packages/torch/optim/adamw.py in _single_tensor_adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable)
#     314                 denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     315             else:
# --> 316                 denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     317
#     318             param.addcdiv_(exp_avg, denom, value=-step_size)
#
# KeyboardInterrupt:

# %%
import pandas as pd


pred_metrics = {}
samples = []

all_preds = pd.read_csv("./newdata_results/test_metrics_with_biochem_1ep.csv").mean()
pred_metrics["all_preds"] = all_preds  

for i in range(5):
    test_metrics_no_pred = pd.read_csv(f'./newdata_results/test_metrics_no_biochem({i}).csv')
    samples.append(test_metrics_pred)
    
pred_metrics["no_pred"] = pd.concat(samples).mean()
for biochem_pred in biochem_cols:

    samples = []
    
    for i in range(5):
        test_metrics_pred = pd.read_csv(f'./newdata_results/test_metrics_only_pred_{biochem_pred}({i}).csv')
        samples.append(test_metrics_pred)
    
    pred_metrics[biochem_pred] = pd.concat(samples).mean()

metrics_df = pd.DataFrame(pred_metrics, index=None).transpose()

print(metrics_df)

# %%
import numpy as np
import matplotlib.pyplot as plt 

index = np.arange(len(metrics_df["accuracy"]))
tags = ["all_preds", "no_pred"] + biochem_cols

fig, axs = plt.subplots(4,2, figsize=(32, 40))

w = 0.8
C = 8

axs[0][0].barh(index, metrics_df["accuracy"], color='b')
axs[0][0].set_title("Accuracy")
axs[0][0].set_yticks(index)
axs[0][0].set_yticklabels(tags) # 0.7,0.775
mean = metrics_df["accuracy"].mean()
std = metrics_df["accuracy"].std()
axs[0][0].set_xlim(mean-C*std,mean+C*std)
axs[0][0].axvline(x = metrics_df["accuracy"]["no_pred"], color = 'k')
axs[0][0].invert_yaxis()  # labels read top-to-bottom

axs[0][1].barh(index, metrics_df["precision"], color='g')
axs[0][1].set_title("Precision")
axs[0][1].set_yticks(index)
axs[0][1].set_yticklabels(tags)
mean = metrics_df["precision"].mean()
std = metrics_df["precision"].std()
axs[0][1].set_xlim(mean-C*std,mean+C*std)
axs[0][1].axvline(x = metrics_df["precision"]["no_pred"], color = 'k')
axs[0][1].invert_yaxis()  # labels read top-to-bottom

axs[1][0].barh(index, metrics_df["f1"], color='r')
axs[1][0].set_title("F1")
axs[1][0].set_yticks(index)
axs[1][0].set_yticklabels(tags)
mean = metrics_df["f1"].mean()
std = metrics_df["f1"].std()
axs[1][0].set_xlim(mean-C*std,mean+C*std)
axs[1][0].axvline(x = metrics_df["f1"]["no_pred"], color = 'k')
axs[1][0].invert_yaxis()  # labels read top-to-bottom

axs[1][1].barh(index, metrics_df["recall"], color='c')
axs[1][1].set_title("Recall")
axs[1][1].set_yticks(index)
axs[1][1].set_yticklabels(tags)
mean = metrics_df["recall"].mean()
std = metrics_df["recall"].std()
axs[1][1].set_xlim(mean-C*std,mean+C*std)
axs[1][1].axvline(x = metrics_df["recall"]["no_pred"], color = 'k')
axs[1][1].invert_yaxis()  # labels read top-to-bottom

axs[2][0].barh(index, metrics_df["specificity"], color='m')
axs[2][0].set_title("Specificity")
axs[2][0].set_yticks(index)
axs[2][0].set_yticklabels(tags)
mean = metrics_df["specificity"].mean()
std = metrics_df["specificity"].std()
axs[2][0].set_xlim(mean-C*std,mean+C*std)
axs[2][0].axvline(x = metrics_df["specificity"]["no_pred"], color = 'k')
axs[2][0].invert_yaxis()  # labels read top-to-bottom

axs[2][1].barh(index, metrics_df["auroc"], color='y')
axs[2][1].set_title("Area under ROC")
axs[2][1].set_yticks(index)
axs[2][1].set_yticklabels(tags)
mean = metrics_df["auroc"].mean()
std = metrics_df["auroc"].std()
axs[2][1].set_xlim(mean-C*std,mean+C*std)
axs[2][1].axvline(x = metrics_df["auroc"]["no_pred"], color = 'k')
axs[2][1].invert_yaxis()  # labels read top-to-bottom

axs[3][0].barh(index, metrics_df["aupr"], color='k')
axs[3][0].set_title("Area under PRC")
axs[3][0].set_yticks(index)
axs[3][0].set_yticklabels(tags)
mean = metrics_df["aupr"].mean()
std = metrics_df["aupr"].std()
axs[3][0].set_xlim(mean-C*std,mean+C*std)
axs[3][0].axvline(x = metrics_df["aupr"]["no_pred"], color = 'k')
axs[3][0].invert_yaxis()  # labels read top-to-bottom


##############



plt.show()
